# %% [markdown]
# # Machine Learning Workflow: Batch Processing
#
# Let us climb up to our learning curve by understanding the impact of batch processing to the ML workflow. Recall that in the previous laboratory notebook, we train our model at once on the training set. In reality, if you have a very large dataset, you need to employ batch processing. The training set is being divided into batches. The illustration below shows the changes of the ML workflow, applying the batch processing concept.
#
# By the end of this laboratory notebook, you will be able to **apply batch processing in any ML classification task.**

# %% [markdown]
# ![workflow2.png](data:image/png;base64,...)

# %% [markdown]
# ## 1. Data Preparation
# We will use again the MNIST dataset as our `raw data`.

# %% [markdown]
# Recall that you can download the `mnist_digits.csv` from this [GDrive](https://drive.google.com/file/d/1eAmVYcpRvkYM7MXb7vTu95zQjWjS1iet/view?usp=sharing).

# %%
import pandas as pd

try: # if csv file is already in Colab, then load
  raw_data = pd.read_csv("C:/Users/DWIGHT LANCE JUMAOAS/don't open this/emerging_technology/emerging-technologies-main/activities/machine_learning_samples/lfw_people.csv")
  print("Loaded lfw_people.csv into a DataFrame.")
except FileNotFoundError: # otherwise, allow user to upload the CSV file
  uploaded = files.upload()
  for filename in uploaded.keys():
      raw_data = pd.read_csv(filename)
      print(f"Loaded {filename} into a DataFrame.")
# Out:
# Loaded lfw_people.csv into a DataFrame.

# %% [markdown]
# There will be no changes when preparing the dataset. So, our next move is to determine the `features` and `ground-truth classes`. Once again, we will represent the array of features as the `X` variable, while the ground-truth classes (or the targets) as the `y` variable.

# %%
X = raw_data.iloc[:, :-1]
y = raw_data.iloc[:, -1]

# %% [markdown]
# Likewise we will perform data splitting: 70% training, 15% validation, and 15% testing.

# %%
from sklearn.model_selection import train_test_split

X_train, X_others, y_train, y_others = train_test_split(
    X, # features
    y, # targets
    train_size=0.7, # 70% training set
    stratify=y, # split according to even distribution of targets
    shuffle=True
)

X_val, X_test, y_val, y_test = train_test_split(
    X_others, # features
    y_others, # targets
    test_size = 0.5, # 15% = 0.5 of 30%
    stratify=y_others, # split according to even distribution of targets
    shuffle=True
)

# %% [markdown]
# Alright! So now, you need to remember that:
#
#
# 1.   `X_train` and `y_train` correspond to the features and targets in the training set.
# 2.   `X_val` and `y_val` correspond to the features and targets in the validation set.
# 3.   `X_test` and `y_test` correspond to the features and targets in the training set.

# %% [markdown]
# ## 2. Training
#
# In this laboratory notebook,we will utilize again the same algorithm, which is the ANN-MLP. We also retain the number of hidden layers and the number of hidden nodes. However, we introduce two new things:
#
#
# 1.   Epoch and batch size
# 2.   Categorical cross-entropy loss

# %%
from sklearn.linear_model import PassiveAggressiveClassifier

# Initialize model
model = PassiveAggressiveClassifier(
    max_iter=1000, 
    C=1,          
    loss="squared_hinge"  
)

# %% [markdown]
# Before we go for training, we need to learn first what are `epoch` and `batch size`.
#
#
# *   `epoch`: refers to one complete pass through the entire training dataset.
# *   `batch_size`: defines the number of samples that are used to update the model's parameters at each step during training.

# %%
epochs = 700
batch_size = 512

# %% [markdown]
# Since we will try to learn by batch size, let us create a function that create batches.

# %%
def get_batches(X, y, batch_size):
    for i in range(0, X.shape[0], batch_size):
        X_batch = X[i:i + batch_size]
        y_batch = y[i:i + batch_size]
        yield X_batch, y_batch

# %% [markdown]
# Also since what we want to do is a multiclass classification, we need to use the `categorical cross-entropy loss`. It is mathematically defined as:
#
# $ Loss = - \sum^{N}_{i=1} \sum^{C}_{c=1} y_{ic} log(p_{ic})$
#
# where,
# * $C$ is the number of classes (here, is 10)
# * $y_{ic}$ is the binary indicator (0 or 1) if class label $c$ is the correct classification for observation $i$
# * $p_{ic}$ is the predicted probability of observation $i$ being of class $c$
#
# But, no need to worry! Because we can call `log_loss` from scikit-learn to compute this value.

# %%
from sklearn.metrics import log_loss

# %% [markdown]
# Now, we begin the training of the model over multiple epochs with batch processing.

# %%
import numpy as np
import copy

history = {'train_losses': [], 'val_losses': [], 'best_model': None, 'best_epoch': 0}
classes = np.unique(y)

for epoch in range(epochs):
    first_batch = True  # reset each epoch

    # Train in mini-batches
    for X_batch, y_batch in get_batches(X_train, y_train, batch_size):
        if first_batch:
            model.partial_fit(X_batch, y_batch, classes=classes)
            first_batch = False
        else:
            model.partial_fit(X_batch, y_batch)

    # --- Training loss ---
    if hasattr(model, "predict_proba"):
        y_train_proba = model.predict_proba(X_train)
    else:
        # fallback for hinge loss: use decision_function -> softmax approximation
        decision = model.decision_function(X_train)
        exp_scores = np.exp(decision - np.max(decision, axis=1, keepdims=True))
        y_train_proba = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)

    y_train_proba = np.clip(y_train_proba, 1e-15, 1 - 1e-15)
    train_loss = log_loss(y_train, y_train_proba)

    # --- Validation loss ---
    if hasattr(model, "predict_proba"):
        y_val_proba = model.predict_proba(X_val)
    else:
        decision = model.decision_function(X_val)
        exp_scores = np.exp(decision - np.max(decision, axis=1, keepdims=True))
        y_val_proba = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)

    y_val_proba = np.clip(y_val_proba, 1e-15, 1 - 1e-15)
    val_loss = log_loss(y_val, y_val_proba)

    print(f"Epoch {epoch+1}/{epochs}: train_loss={train_loss:.4f}, val_loss={val_loss:.4f}")

    # Save best model (deepcopy to freeze weights)
    if (history['best_model'] is None) or (val_loss < min(history['val_losses'], default=float("inf"))):
        history['best_model'] = copy.deepcopy(model)
        history['best_epoch'] = epoch

    history['train_losses'].append(train_loss)
    history['val_losses'].append(val_loss)
# Out:
# Epoch 1/700: train_loss=1.4367, val_loss=1.5081
# Epoch 2/700: train_loss=1.2822, val_loss=1.3574
# Epoch 3/700: train_loss=1.4747, val_loss=1.5699
# Epoch 4/700: train_loss=1.0036, val_loss=1.1252
# Epoch 5/700: train_loss=1.0231, val_loss=1.1525
# Epoch 6/700: train_loss=0.8452, val_loss=1.0071
# Epoch 7/700: train_loss=0.9759, val_loss=1.1602
# Epoch 8/700: train_loss=0.8444, val_loss=1.0226
# Epoch 9/700: train_loss=0.7161, val_loss=0.9068
# Epoch 10/700: train_loss=0.8335, val_loss=1.0035
# Epoch 11/700: train_loss=0.7859, val_loss=0.9834
# Epoch 12/700: train_loss=0.6735, val_loss=0.8654
# Epoch 13/700: train_loss=0.7147, val_loss=0.9346
# Epoch 14/700: train_loss=0.6455, val_loss=0.8639
# Epoch 15/700: train_loss=0.6319, val_loss=0.8365
# Epoch 16/700: train_loss=0.7618, val_loss=0.9643
# Epoch 17/700: train_loss=0.8607, val_loss=1.0680
# Epoch 18/700: train_loss=0.5709, val_loss=0.8140
# Epoch 19/700: train_loss=0.6347, val_loss=0.8569
# Epoch 20/700: train_loss=0.7949, val_loss=1.0607
# Epoch 21/700: train_loss=0.6289, val_loss=0.8863
# Epoch 22/700: train_loss=0.5106, val_loss=0.7522
# Epoch 23/700: train_loss=0.5293, val_loss=0.7864
# Epoch 24/700: train_loss=0.4933, val_loss=0.7482
# Epoch 25/700: train_loss=0.5581, val_loss=0.7931
# Epoch 26/700: train_loss=0.5978, val_loss=0.8468
# Epoch 27/700: train_loss=0.5521, val_loss=0.7983
# Epoch 28/700: train_loss=0.5241, val_loss=0.7839
# Epoch 29/700: train_loss=0.4745, val_loss=0.7368
# Epoch 30/700: train_loss=0.5221, val_loss=0.7886
# Epoch 31/700: train_loss=0.5579, val_loss=0.8240
# Epoch 32/700: train_loss=0.4545, val_loss=0.7214
# Epoch 33/700: train_loss=0.4630, val_loss=0.7337
# Epoch 34/700: train_loss=0.4179, val_loss=0.7032
# Epoch 35/700: train_loss=0.5059, val_loss=0.7940
# Epoch 36/700: train_loss=0.4193, val_loss=0.7082
# Epoch 37/700: train_loss=0.4299, val_loss=0.7129
# Epoch 38/700: train_loss=0.4943, val_loss=0.7572
# Epoch 39/700: train_loss=0.5747, val_loss=0.8523
# Epoch 40/700: train_loss=0.4606, val_loss=0.7417
# Epoch 41/700: train_loss=0.4344, val_loss=0.7339
# Epoch 42/700: train_loss=0.4690, val_loss=0.7459
# Epoch 43/700: train_loss=0.4792, val_loss=0.7722
# Epoch 44/700: train_loss=0.4306, val_loss=0.7443
# Epoch 45/700: train_loss=0.3854, val_loss=0.6781
# Epoch 46/700: train_loss=0.5170, val_loss=0.8101
# Epoch 47/700: train_loss=0.3669, val_loss=0.6817
# Epoch 48/700: train_loss=0.3943, val_loss=0.7113
# Epoch 49/700: train_loss=0.3697, val_loss=0.6708
# Epoch 50/700: train_loss=0.3947, val_loss=0.7125
# Epoch 51/700: train_loss=0.3892, val_loss=0.6944
# Epoch 52/700: train_loss=0.3486, val_loss=0.6737
# Epoch 53/700: train_loss=0.4074, val_loss=0.7235
# Epoch 54/700: train_loss=0.3683, val_loss=0.6856
# Epoch 55/700: train_loss=0.3607, val_loss=0.6783
# Epoch 56/700: train_loss=0.3514, val_loss=0.6646
# Epoch 57/700: train_loss=0.4301, val_loss=0.7540
# Epoch 58/700: train_loss=0.3516, val_loss=0.6861
# Epoch 59/700: train_loss=0.3538, val_loss=0.6913
# Epoch 60/700: train_loss=0.4810, val_loss=0.7958
# Epoch 61/700: train_loss=0.3749, val_loss=0.7106
# Epoch 62/700: train_loss=0.3410, val_loss=0.6753
# Epoch 63/700: train_loss=0.3246, val_loss=0.6572
# Epoch 64/700: train_loss=0.3405, val_loss=0.6841
# Epoch 65/700: train_loss=0.3533, val_loss=0.6871
# Epoch 66/700: train_loss=0.4432, val_loss=0.8044
# Epoch 67/700: train_loss=0.3422, val_loss=0.6889
# Epoch 68/700: train_loss=0.3444, val_loss=0.6820
# Epoch 69/700: train_loss=0.3752, val_loss=0.7117
# Epoch 70/700: train_loss=0.3381, val_loss=0.6813
# Epoch 71/700: train_loss=0.3128, val_loss=0.6603
# Epoch 72/700: train_loss=0.3685, val_loss=0.7123
# Epoch 73/700: train_loss=0.3155, val_loss=0.6684
# Epoch 74/700: train_loss=0.3471, val_loss=0.6818
# Epoch 75/700: train_loss=0.3631, val_loss=0.6971
# Epoch 76/700: train_loss=0.3273, val_loss=0.6764
# Epoch 77/700: train_loss=0.3022, val_loss=0.6569
# Epoch 78/700: train_loss=0.3107, val_loss=0.6548
# Epoch 79/700: train_loss=0.4015, val_loss=0.7655
# Epoch 80/700: train_loss=0.3351, val_loss=0.6695
# Epoch 81/700: train_loss=0.3382, val_loss=0.6922
# Epoch 82/700: train_loss=0.3478, val_loss=0.7071
# Epoch 83/700: train_loss=0.2978, val_loss=0.6588
# Epoch 84/700: train_loss=0.3592, val_loss=0.7301
# Epoch 85/700: train_loss=0.3363, val_loss=0.6897
# Epoch 86/700: train_loss=0.2936, val_loss=0.6715
# Epoch 87/700: train_loss=0.2808, val_loss=0.6624
# Epoch 88/700: train_loss=0.2851, val_loss=0.6587
# Epoch 89/700: train_loss=0.3454, val_loss=0.7132
# Epoch 90/700: train_loss=0.2856, val_loss=0.6614
# Epoch 91/700: train_loss=0.3140, val_loss=0.6736
# Epoch 92/700: train_loss=0.2755, val_loss=0.6528
# Epoch 93/700: train_loss=0.2815, val_loss=0.6453
# Epoch 94/700: train_loss=0.2983, val_loss=0.6767
# Epoch 95/700: train_loss=0.2801, val_loss=0.6713
# Epoch 96/700: train_loss=0.2711, val_loss=0.6504
# Epoch 97/700: train_loss=0.2841, val_loss=0.6683
# Epoch 98/700: train_loss=0.2850, val_loss=0.6606
# Epoch 99/700: train_loss=0.2726, val_loss=0.6547
# Epoch 100/700: train_loss=0.2733, val_loss=0.6560
# Epoch 101/700: train_loss=0.2873, val_loss=0.6522
# Epoch 102/700: train_loss=0.3218, val_loss=0.6930
# Epoch 103/700: train_loss=0.2791, val_loss=0.6582
# Epoch 104/700: train_loss=0.2741, val_loss=0.6502
# Epoch 105/700: train_loss=0.2711, val_loss=0.6424
# Epoch 106/700: train_loss=0.3131, val_loss=0.6854
# Epoch 107/700: train_loss=0.2776, val_loss=0.6620
# Epoch 108/700: train_loss=0.2949, val_loss=0.6870
# Epoch 109/700: train_loss=0.3013, val_loss=0.6676
# Epoch 110/700: train_loss=0.2729, val_loss=0.6676
# Epoch 111/700: train_loss=0.2741, val_loss=0.6650
# Epoch 112/700: train_loss=0.2552, val_loss=0.6381
# Epoch 113/700: train_loss=0.2606, val_loss=0.6606
# Epoch 114/700: train_loss=0.2662, val_loss=0.6486
# Epoch 115/700: train_loss=0.2669, val_loss=0.6657
# Epoch 116/700: train_loss=0.2480, val_loss=0.6385
# Epoch 117/700: train_loss=0.3151, val_loss=0.7153
# Epoch 118/700: train_loss=0.2766, val_loss=0.6707
# Epoch 119/700: train_loss=0.2893, val_loss=0.6778
# Epoch 120/700: train_loss=0.2974, val_loss=0.7095
# Epoch 121/700: train_loss=0.2895, val_loss=0.6882
# Epoch 122/700: train_loss=0.2472, val_loss=0.6445
# Epoch 123/700: train_loss=0.2737, val_loss=0.6720
# Epoch 124/700: train_loss=0.2392, val_loss=0.6473
# Epoch 125/700: train_loss=0.2365, val_loss=0.6492
# Epoch 126/700: train_loss=0.2546, val_loss=0.6563
# Epoch 127/700: train_loss=0.2487, val_loss=0.6502
# Epoch 128/700: train_loss=0.2667, val_loss=0.6755
# Epoch 129/700: train_loss=0.2338, val_loss=0.6363
# Epoch 130/700: train_loss=0.2972, val_loss=0.6798
# Epoch 131/700: train_loss=0.2595, val_loss=0.6510
# Epoch 132/700: train_loss=0.2378, val_loss=0.6457
# Epoch 133/700: train_loss=0.2679, val_loss=0.6602
# Epoch 134/700: train_loss=0.2471, val_loss=0.6401
# Epoch 135/700: train_loss=0.2799, val_loss=0.6823
# Epoch 136/700: train_loss=0.2335, val_loss=0.6420
# Epoch 137/700: train_loss=0.2413, val_loss=0.6515
# Epoch 138/700: train_loss=0.2596, val_loss=0.6485
# Epoch 139/700: train_loss=0.2248, val_loss=0.6413
# Epoch 140/700: train_loss=0.2304, val_loss=0.6515
# Epoch 141/700: train_loss=0.2528, val_loss=0.6513
# Epoch 142/700: train_loss=0.2392, val_loss=0.6434
# Epoch 143/700: train_loss=0.2316, val_loss=0.6389
# Epoch 144/700: train_loss=0.2831, val_loss=0.6947
# Epoch 145/700: train_loss=0.2297, val_loss=0.6395
# Epoch 146/700: train_loss=0.2494, val_loss=0.6622
# Epoch 147/700: train_loss=0.2512, val_loss=0.6647
# Epoch 148/700: train_loss=0.2544, val_loss=0.6703
# Epoch 149/700: train_loss=0.2668, val_loss=0.6784
# Epoch 150/700: train_loss=0.2517, val_loss=0.6689
# Epoch 151/700: train_loss=0.2370, val_loss=0.6477
# Epoch 152/700: train_loss=0.2347, val_loss=0.6410
# Epoch 153/700: train_loss=0.2759, val_loss=0.6812
# Epoch 154/700: train_loss=0.2720, val_loss=0.6858
# Epoch 155/700: train_loss=0.2426, val_loss=0.6489
# Epoch 156/700: train_loss=0.2598, val_loss=0.6862
# Epoch 157/700: train_loss=0.2345, val_loss=0.6426
# Epoch 158/700: train_loss=0.2204, val_loss=0.6363
# Epoch 159/700: train_loss=0.2424, val_loss=0.6517
# Epoch 160/700: train_loss=0.2492, val_loss=0.6665
# Epoch 161/700: train_loss=0.2225, val_loss=0.6411
# Epoch 162/700: train_loss=0.2378, val_loss=0.6529
# Epoch 163/700: train_loss=0.2212, val_loss=0.6505
# Epoch 164/700: train_loss=0.2207, val_loss=0.6482
# Epoch 165/700: train_loss=0.2462, val_loss=0.6705
# Epoch 166/700: train_loss=0.2177, val_loss=0.6439
# Epoch 167/700: train_loss=0.2362, val_loss=0.6549
# Epoch 168/700: train_loss=0.2397, val_loss=0.6556
# Epoch 169/700: train_loss=0.2365, val_loss=0.6540
# Epoch 170/700: train_loss=0.2262, val_loss=0.6687
# Epoch 171/700: train_loss=0.2117, val_loss=0.6442
# Epoch 172/700: train_loss=0.2238, val_loss=0.6625
# Epoch 173/700: train_loss=0.2360, val_loss=0.6493
# Epoch 174/700: train_loss=0.2136, val_loss=0.6350
# Epoch 175/700: train_loss=0.2562, val_loss=0.6781
# Epoch 176/700: train_loss=0.2242, val_loss=0.6458
# Epoch 177/700: train_loss=0.2349, val_loss=0.6562
# Epoch 178/700: train_loss=0.2219, val_loss=0.6488
# Epoch 179/700: train_loss=0.2241, val_loss=0.6421
# Epoch 180/700: train_loss=0.2354, val_loss=0.6560
# Epoch 181/700: train_loss=0.2281, val_loss=0.6480
# Epoch 182/700: train_loss=0.2275, val_loss=0.6455
# Epoch 183/700: train_loss=0.2252, val_loss=0.6436
# Epoch 184/700: train_loss=0.2139, val_loss=0.6376
# Epoch 185/700: train_loss=0.2438, val_loss=0.6725
# Epoch 186/700: train_loss=0.2195, val_loss=0.6537
# Epoch 187/700: train_loss=0.2047, val_loss=0.6378
# Epoch 188/700: train_loss=0.2119, val_loss=0.6355
# Epoch 189/700: train_loss=0.2153, val_loss=0.6420
# Epoch 190/700: train_loss=0.2067, val_loss=0.6412
# Epoch 191/700: train_loss=0.2303, val_loss=0.6562
# Epoch 192/700: train_loss=0.2038, val_loss=0.6448
# Epoch 193/700: train_loss=0.2159, val_loss=0.6491
# Epoch 194/700: train_loss=0.2149, val_loss=0.6373
# Epoch 195/700: train_loss=0.2322, val_loss=0.6593
# Epoch 196/700: train_loss=0.2104, val_loss=0.6436
# Epoch 197/700: train_loss=0.2501, val_loss=0.6701
# Epoch 198/700: train_loss=0.2133, val_loss=0.6636
# Epoch 199/700: train_loss=0.2297, val_loss=0.6566
# Epoch 200/700: train_loss=0.2018, val_loss=0.6495
# Epoch 201/700: train_loss=0.2205, val_loss=0.6493
# Epoch 202/700: train_loss=0.2030, val_loss=0.6506
# Epoch 203/700: train_loss=0.2198, val_loss=0.6540
# Epoch 204/700: train_loss=0.2015, val_loss=0.6428
# Epoch 205/700: train_loss=0.2174, val_loss=0.6551
# Epoch 206/700: train_loss=0.1976, val_loss=0.6417
# Epoch 207/700: train_loss=0.2089, val_loss=0.6598
# Epoch 208/700: train_loss=0.2241, val_loss=0.6552
# Epoch 209/700: train_loss=0.2193, val_loss=0.6566
# Epoch 210/700: train_loss=0.1982, val_loss=0.6497
# Epoch 211/700: train_loss=0.2125, val_loss=0.6440
# Epoch 212/700: train_loss=0.2111, val_loss=0.6631
# Epoch 213/700: train_loss=0.2026, val_loss=0.6433
# Epoch 214/700: train_loss=0.2065, val_loss=0.6570
# Epoch 215/700: train_loss=0.2184, val_loss=0.6540
# Epoch 216/700: train_loss=0.2052, val_loss=0.6441
# Epoch 217/700: train_loss=0.2013, val_loss=0.6535
# Epoch 218/700: train_loss=0.2061, val_loss=0.6501
# Epoch 219/700: train_loss=0.2056, val_loss=0.6548
# Epoch 220/700: train_loss=0.2311, val_loss=0.6599
# Epoch 221/700: train_loss=0.2022, val_loss=0.6554
# Epoch 222/700: train_loss=0.2063, val_loss=0.6509
# Epoch 223/700: train_loss=0.2002, val_loss=0.6429
# Epoch 224/700: train_loss=0.2022, val_loss=0.6495
# Epoch 225/700: train_loss=0.2099, val_loss=0.6507
# Epoch 226/700: train_loss=0.2098, val_loss=0.6492
# Epoch 227/700: train_loss=0.1990, val_loss=0.6405
# Epoch 228/700: train_loss=0.2091, val_loss=0.6585
# Epoch 229/700: train_loss=0.2217, val_loss=0.6645
# Epoch 230/700: train_loss=0.1939, val_loss=0.6447
# Epoch 231/700: train_loss=0.2207, val_loss=0.6586
# Epoch 232/700: train_loss=0.1925, val_loss=0.6453
# Epoch 233/700: train_loss=0.1978, val_loss=0.6462
# Epoch 234/700: train_loss=0.2223, val_loss=0.6725
# Epoch 235/700: train_loss=0.2120, val_loss=0.6554
# Epoch 236/700: train_loss=0.2005, val_loss=0.6570
# Epoch 237/700: train_loss=0.2062, val_loss=0.6507
# Epoch 238/700: train_loss=0.1979, val_loss=0.6462
# Epoch 239/700: train_loss=0.1930, val_loss=0.6501
# Epoch 240/700: train_loss=0.2228, val_loss=0.6688
# Epoch 241/700: train_loss=0.2098, val_loss=0.6485
# Epoch 242/700: train_loss=0.2015, val_loss=0.6474
# Epoch 243/700: train_loss=0.2262, val_loss=0.6767
# Epoch 244/700: train_loss=0.2004, val_loss=0.6483
# Epoch 245/700: train_loss=0.2001, val_loss=0.6471
# Epoch 246/700: train_loss=0.2081, val_loss=0.6626
# Epoch 247/700: train_loss=0.2110, val_loss=0.6559
# Epoch 248/700: train_loss=0.2087, val_loss=0.6546
# Epoch 249/700: train_loss=0.2191, val_loss=0.6698
# Epoch 250/700: train_loss=0.2053, val_loss=0.6606
# Epoch 251/700: train_loss=0.1897, val_loss=0.6520
# Epoch 252/700: train_loss=0.1879, val_loss=0.6397
# Epoch 253/700: train_loss=0.1885, val_loss=0.6499
# Epoch 254/700: train_loss=0.1964, val_loss=0.6537
# Epoch 255/700: train_loss=0.1991, val_loss=0.6487
# Epoch 256/700: train_loss=0.2006, val_loss=0.6489
# Epoch 257/700: train_loss=0.1944, val_loss=0.6514
# Epoch 258/700: train_loss=0.1996, val_loss=0.6544
# Epoch 259/700: train_loss=0.2009, val_loss=0.6543
# Epoch 260/700: train_loss=0.2078, val_loss=0.6666
# Epoch 261/700: train_loss=0.1875, val_loss=0.6420
# Epoch 262/700: train_loss=0.1867, val_loss=0.6482
# Epoch 263/700: train_loss=0.1860, val_loss=0.6435
# Epoch 264/700: train_loss=0.1881, val_loss=0.6430
# Epoch 265/700: train_loss=0.1923, val_loss=0.6495
# Epoch 266/700: train_loss=0.1901, val_loss=0.6507
# Epoch 267/700: train_loss=0.1986, val_loss=0.6524
# Epoch 268/700: train_loss=0.1951, val_loss=0.6483
# Epoch 269/700: train_loss=0.1999, val_loss=0.6534
# Epoch 270/700: train_loss=0.1914, val_loss=0.6462
# Epoch 271/700: train_loss=0.1849, val_loss=0.6518
# Epoch 272/700: train_loss=0.1983, val_loss=0.6665
# Epoch 273/700: train_loss=0.1861, val_loss=0.6443
# Epoch 274/700: train_loss=0.2180, val_loss=0.6785
# Epoch 275/700: train_loss=0.1804, val_loss=0.6507
# Epoch 276/700: train_loss=0.1970, val_loss=0.6556
# Epoch 277/700: train_loss=0.2026, val_loss=0.6552
# Epoch 278/700: train_loss=0.1926, val_loss=0.6499
# Epoch 279/700: train_loss=0.2027, val_loss=0.6586
# Epoch 280/700: train_loss=0.1826, val_loss=0.6477
# Epoch 281/700: train_loss=0.2016, val_loss=0.6587
# Epoch 282/700: train_loss=0.1820, val_loss=0.6505
# Epoch 283/700: train_loss=0.2160, val_loss=0.6691
# Epoch 284/700: train_loss=0.1975, val_loss=0.6593
# Epoch 285/700: train_loss=0.1884, val_loss=0.6459
# Epoch 286/700: train_loss=0.1905, val_loss=0.6513
# Epoch 287/700: train_loss=0.1855, val_loss=0.6457
# Epoch 288/700: train_loss=0.2013, val_loss=0.6580
# Epoch 289/700: train_loss=0.1988, val_loss=0.6602
# Epoch 290/700: train_loss=0.1987, val_loss=0.6575
# Epoch 291/700: train_loss=0.1833, val_loss=0.6538
# Epoch 292/700: train_loss=0.1992, val_loss=0.6588
# Epoch 293/700: train_loss=0.2189, val_loss=0.6729
# Epoch 294/700: train_loss=0.1871, val_loss=0.6533
# Epoch 295/700: train_loss=0.1859, val_loss=0.6477
# Epoch 296/700: train_loss=0.2076, val_loss=0.6689
# Epoch 297/700: train_loss=0.1926, val_loss=0.6517
# Epoch 298/700: train_loss=0.1874, val_loss=0.6514
# Epoch 299/700: train_loss=0.1994, val_loss=0.6614
# Epoch 300/700: train_loss=0.1880, val_loss=0.6497
# Epoch 301/700: train_loss=0.1784, val_loss=0.6487
# Epoch 302/700: train_loss=0.1806, val_loss=0.6466
# Epoch 303/700: train_loss=0.2024, val_loss=0.6651
# Epoch 304/700: train_loss=0.1977, val_loss=0.6549
# Epoch 305/700: train_loss=0.1990, val_loss=0.6670
# Epoch 306/700: train_loss=0.1848, val_loss=0.6476
# Epoch 307/700: train_loss=0.1765, val_loss=0.6532
# Epoch 308/700: train_loss=0.1861, val_loss=0.6574
# Epoch 309/700: train_loss=0.1841, val_loss=0.6490
# Epoch 310/700: train_loss=0.2016, val_loss=0.6637
# Epoch 311/700: train_loss=0.1976, val_loss=0.6639
# Epoch 312/700: train_loss=0.1823, val_loss=0.6512
# Epoch 313/700: train_loss=0.2012, val_loss=0.6642
# Epoch 314/700: train_loss=0.1987, val_loss=0.6632
# Epoch 315/700: train_loss=0.2033, val_loss=0.6759
# Epoch 316/700: train_loss=0.1862, val_loss=0.6537
# Epoch 317/700: train_loss=0.1944, val_loss=0.6598
# Epoch 318/700: train_loss=0.1874, val_loss=0.6518
# Epoch 319/700: train_loss=0.1806, val_loss=0.6569
# Epoch 320/700: train_loss=0.1832, val_loss=0.6515
# Epoch 321/700: train_loss=0.1822, val_loss=0.6524
# Epoch 322/700: train_loss=0.1849, val_loss=0.6544
# Epoch 323/700: train_loss=0.1838, val_loss=0.6512
# Epoch 324/700: train_loss=0.1884, val_loss=0.6598
# Epoch 325/700: train_loss=0.1814, val_loss=0.6521
# Epoch 326/700: train_loss=0.1985, val_loss=0.6649
# Epoch 327/700: train_loss=0.1785, val_loss=0.6539
# Epoch 328/700: train_loss=0.1797, val_loss=0.6533
# Epoch 329/700: train_loss=0.1939, val_loss=0.6645
# Epoch 330/700: train_loss=0.1889, val_loss=0.6549
# Epoch 331/700: train_loss=0.1932, val_loss=0.6592
# Epoch 332/700: train_loss=0.1961, val_loss=0.6612
# Epoch 333/700: train_loss=0.2007, val_loss=0.6649
# Epoch 334/700: train_loss=0.1768, val_loss=0.6516
# Epoch 335/700: train_loss=0.1879, val_loss=0.6546
# Epoch 336/700: train_loss=0.1814, val_loss=0.6535
# Epoch 337/700: train_loss=0.1881, val_loss=0.6577
# Epoch 338/700: train_loss=0.1857, val_loss=0.6561
# Epoch 339/700: train_loss=0.1946, val_loss=0.6639
# Epoch 340/700: train_loss=0.1914, val_loss=0.6659
# Epoch 341/700: train_loss=0.1764, val_loss=0.6526
# Epoch 342/700: train_loss=0.1985, val_loss=0.6671
# Epoch 343/700: train_loss=0.1912, val_loss=0.6603
# Epoch 344/700: train_loss=0.1934, val_loss=0.6675
# Epoch 345/700: train_loss=0.1804, val_loss=0.6513
# Epoch 346/700: train_loss=0.1851, val_loss=0.6596
# Epoch 347/700: train_loss=0.1860, val_loss=0.6560
# Epoch 348/700: train_loss=0.1883, val_loss=0.6630
# Epoch 349/700: train_loss=0.1763, val_loss=0.6484
# Epoch 350/700: train_loss=0.1812, val_loss=0.6541
# Epoch 351/700: train_loss=0.1813, val_loss=0.6547
# Epoch 352/700: train_loss=0.1755, val_loss=0.6519
# Epoch 353/700: train_loss=0.1854, val_loss=0.6583
# Epoch 354/700: train_loss=0.1767, val_loss=0.6487
# Epoch 355/700: train_loss=0.1773, val_loss=0.6518
# Epoch 356/700: train_loss=0.1857, val_loss=0.6572
# Epoch 357/700: train_loss=0.1773, val_loss=0.6538
# Epoch 358/700: train_loss=0.1790, val_loss=0.6517
# Epoch 359/700: train_loss=0.1711, val_loss=0.6490
# Epoch 360/700: train_loss=0.1766, val_loss=0.6523
# Epoch 361/700: train_loss=0.1716, val_loss=0.6514
# Epoch 362/700: train_loss=0.1862, val_loss=0.6572
# Epoch 363/700: train_loss=0.1783, val_loss=0.6533
# Epoch 364/700: train_loss=0.1825, val_loss=0.6546
# Epoch 365/700: train_loss=0.1765, val_loss=0.6520
# Epoch 366/700: train_loss=0.1866, val_loss=0.6588
# Epoch 367/700: train_loss=0.1763, val_loss=0.6551
# Epoch 368/700: train_loss=0.1874, val_loss=0.6597
# Epoch 369/700: train_loss=0.1808, val_loss=0.6545
# Epoch 370/700: train_loss=0.1864, val_loss=0.6558
# Epoch 371/700: train_loss=0.1882, val_loss=0.6607
# Epoch 372/700: train_loss=0.1916, val_loss=0.6664
# Epoch 373/700: train_loss=0.1716, val_loss=0.6568
# Epoch 374/700: train_loss=0.1852, val_loss=0.6588
# Epoch 375/700: train_loss=0.1931, val_loss=0.6679
# Epoch 376/700: train_loss=0.1747, val_loss=0.6525
# Epoch 377/700: train_loss=0.1779, val_loss=0.6535
# Epoch 378/700: train_loss=0.1802, val_loss=0.6541
# Epoch 379/700: train_loss=0.1811, val_loss=0.6625
# Epoch 380/700: train_loss=0.1804, val_loss=0.6589
# Epoch 381/700: train_loss=0.1754, val_loss=0.6551
# Epoch 382/700: train_loss=0.1707, val_loss=0.6542
# Epoch 383/700: train_loss=0.1770, val_loss=0.6539
# Epoch 384/700: train_loss=0.1845, val_loss=0.6631
# Epoch 385/700: train_loss=0.1790, val_loss=0.6540
# Epoch 386/700: train_loss=0.1799, val_loss=0.6560
# Epoch 387/700: train_loss=0.1752, val_loss=0.6571
# Epoch 388/700: train_loss=0.1793, val_loss=0.6532
# Epoch 389/700: train_loss=0.1838, val_loss=0.6616
# Epoch 390/700: train_loss=0.1796, val_loss=0.6555
# Epoch 391/700: train_loss=0.1858, val_loss=0.6603
# Epoch 392/700: train_loss=0.1731, val_loss=0.6548
# Epoch 393/700: train_loss=0.1819, val_loss=0.6595
# Epoch 394/700: train_loss=0.1728, val_loss=0.6547
# Epoch 395/700: train_loss=0.1814, val_loss=0.6585
# Epoch 396/700: train_loss=0.1805, val_loss=0.6566
# Epoch 397/700: train_loss=0.1872, val_loss=0.6645
# Epoch 398/700: train_loss=0.1722, val_loss=0.6546
# Epoch 399/700: train_loss=0.1909, val_loss=0.6683
# Epoch 400/700: train_loss=0.1823, val_loss=0.6611
# Epoch 401/700: train_loss=0.1865, val_loss=0.6682
# Epoch 402/700: train_loss=0.1800, val_loss=0.6606
# Epoch 403/700: train_loss=0.1758, val_loss=0.6569
# Epoch 404/700: train_loss=0.1724, val_loss=0.6515
# Epoch 405/700: train_loss=0.1772, val_loss=0.6565
# Epoch 406/700: train_loss=0.1781, val_loss=0.6582
# Epoch 407/700: train_loss=0.1817, val_loss=0.6579
# Epoch 408/700: train_loss=0.1732, val_loss=0.6555
# Epoch 409/700: train_loss=0.1827, val_loss=0.6607
# Epoch 410/700: train_loss=0.1699, val_loss=0.6543
# Epoch 411/700: train_loss=0.1695, val_loss=0.6552
# Epoch 412/700: train_loss=0.1720, val_loss=0.6527
# Epoch 413/700: train_loss=0.1771, val_loss=0.6573
# Epoch 414/700: train_loss=0.1823, val_loss=0.6617
# Epoch 415/700: train_loss=0.1723, val_loss=0.6629
# Epoch 416/700: train_loss=0.1726, val_loss=0.6555
# Epoch 417/700: train_loss=0.1793, val_loss=0.6603
# Epoch 418/700: train_loss=0.1752, val_loss=0.6555
# Epoch 419/700: train_loss=0.1775, val_loss=0.6616
# Epoch 420/700: train_loss=0.1857, val_loss=0.6658
# Epoch 421/700: train_loss=0.1740, val_loss=0.6589
# Epoch 422/700: train_loss=0.1708, val_loss=0.6546
# Epoch 423/700: train_loss=0.1700, val_loss=0.6553
# Epoch 424/700: train_loss=0.1817, val_loss=0.6614
# Epoch 425/700: train_loss=0.1694, val_loss=0.6549
# Epoch 426/700: train_loss=0.1718, val_loss=0.6558
# Epoch 427/700: train_loss=0.1782, val_loss=0.6593
# Epoch 428/700: train_loss=0.1696, val_loss=0.6556
# Epoch 429/700: train_loss=0.1683, val_loss=0.6531
# Epoch 430/700: train_loss=0.1772, val_loss=0.6635
# Epoch 431/700: train_loss=0.1678, val_loss=0.6589
# Epoch 432/700: train_loss=0.1763, val_loss=0.6587
# Epoch 433/700: train_loss=0.1760, val_loss=0.6576
# Epoch 434/700: train_loss=0.1763, val_loss=0.6579
# Epoch 435/700: train_loss=0.1789, val_loss=0.6618
# Epoch 436/700: train_loss=0.1747, val_loss=0.6567
# Epoch 437/700: train_loss=0.1719, val_loss=0.6567
# Epoch 438/700: train_loss=0.1761, val_loss=0.6628
# Epoch 439/700: train_loss=0.1786, val_loss=0.6609
# Epoch 440/700: train_loss=0.1878, val_loss=0.6664
# Epoch 441/700: train_loss=0.1758, val_loss=0.6588
# Epoch 442/700: train_loss=0.1800, val_loss=0.6624
# Epoch 443/700: train_loss=0.1780, val_loss=0.6605
# Epoch 444/700: train_loss=0.1743, val_loss=0.6589
# Epoch 445/700: train_loss=0.1732, val_loss=0.6603
# Epoch 446/700: train_loss=0.1732, val_loss=0.6578
# Epoch 447/700: train_loss=0.1747, val_loss=0.6611
# Epoch 448/700: train_loss=0.1693, val_loss=0.6545
# Epoch 449/700: train_loss=0.1755, val_loss=0.6586
# Epoch 450/700: train_loss=0.1807, val_loss=0.6641
# Epoch 451/700: train_loss=0.1709, val_loss=0.6569
# Epoch 452/700: train_loss=0.1691, val_loss=0.6579
# Epoch 453/700: train_loss=0.1695, val_loss=0.6567
# Epoch 454/700: train_loss=0.1776, val_loss=0.6622
# Epoch 455/700: train_loss=0.1709, val_loss=0.6571
# Epoch 456/700: train_loss=0.1720, val_loss=0.6595
# Epoch 457/700: train_loss=0.1761, val_loss=0.6607
# Epoch 458/700: train_loss=0.1696, val_loss=0.6584
# Epoch 459/700: train_loss=0.1758, val_loss=0.6604
# Epoch 460/700: train_loss=0.1693, val_loss=0.6580
# Epoch 461/700: train_loss=0.1712, val_loss=0.6580
# Epoch 462/700: train_loss=0.1717, val_loss=0.6577
# Epoch 463/700: train_loss=0.1786, val_loss=0.6602
# Epoch 464/700: train_loss=0.1711, val_loss=0.6572
# Epoch 465/700: train_loss=0.1657, val_loss=0.6591
# Epoch 466/700: train_loss=0.1733, val_loss=0.6617
# Epoch 467/700: train_loss=0.1697, val_loss=0.6562
# Epoch 468/700: train_loss=0.1775, val_loss=0.6622
# Epoch 469/700: train_loss=0.1766, val_loss=0.6637
# Epoch 470/700: train_loss=0.1689, val_loss=0.6577
# Epoch 471/700: train_loss=0.1773, val_loss=0.6630
# Epoch 472/700: train_loss=0.1680, val_loss=0.6589
# Epoch 473/700: train_loss=0.1694, val_loss=0.6595
# Epoch 474/700: train_loss=0.1694, val_loss=0.6586
# Epoch 475/700: train_loss=0.1673, val_loss=0.6581
# Epoch 476/700: train_loss=0.1735, val_loss=0.6608
# Epoch 477/700: train_loss=0.1673, val_loss=0.6564
# Epoch 478/700: train_loss=0.1704, val_loss=0.6604
# Epoch 479/700: train_loss=0.1714, val_loss=0.6585
# Epoch 480/700: train_loss=0.1729, val_loss=0.6604
# Epoch 481/700: train_loss=0.1698, val_loss=0.6620
# Epoch 482/700: train_loss=0.1795, val_loss=0.6669
# Epoch 483/700: train_loss=0.1731, val_loss=0.6601
# Epoch 484/700: train_loss=0.1747, val_loss=0.6646
# Epoch 485/700: train_loss=0.1755, val_loss=0.6628
# Epoch 486/700: train_loss=0.1721, val_loss=0.6627
# Epoch 487/700: train_loss=0.1710, val_loss=0.6591
# Epoch 488/700: train_loss=0.1755, val_loss=0.6631
# Epoch 489/700: train_loss=0.1720, val_loss=0.6584
# Epoch 490/700: train_loss=0.1670, val_loss=0.6609
# Epoch 491/700: train_loss=0.1710, val_loss=0.6594
# Epoch 492/700: train_loss=0.1711, val_loss=0.6611
# Epoch 493/700: train_loss=0.1700, val_loss=0.6617
# Epoch 494/700: train_loss=0.1697, val_loss=0.6603
# Epoch 495/700: train_loss=0.1717, val_loss=0.6628
# Epoch 496/700: train_loss=0.1713, val_loss=0.6599
# Epoch 497/700: train_loss=0.1762, val_loss=0.6647
# Epoch 498/700: train_loss=0.1693, val_loss=0.6610
# Epoch 499/700: train_loss=0.1731, val_loss=0.6639
# Epoch 500/700: train_loss=0.1756, val_loss=0.6665
# Epoch 501/700: train_loss=0.1751, val_loss=0.6664
# Epoch 502/700: train_loss=0.1678, val_loss=0.6594
# Epoch 503/700: train_loss=0.1689, val_loss=0.6586
# Epoch 504/700: train_loss=0.1717, val_loss=0.6637
# Epoch 505/700: train_loss=0.1673, val_loss=0.6607
# Epoch 506/700: train_loss=0.1690, val_loss=0.6605
# Epoch 507/700: train_loss=0.1713, val_loss=0.6605
# Epoch 508/700: train_loss=0.1739, val_loss=0.6637
# Epoch 509/700: train_loss=0.1694, val_loss=0.6612
# Epoch 510/700: train_loss=0.1703, val_loss=0.6613
# Epoch 511/700: train_loss=0.1683, val_loss=0.6590
# Epoch 512/700: train_loss=0.1675, val_loss=0.6601
# Epoch 513/700: train_loss=0.1731, val_loss=0.6640
# Epoch 514/700: train_loss=0.1700, val_loss=0.6597
# Epoch 515/700: train_loss=0.1721, val_loss=0.6632
# Epoch 516/700: train_loss=0.1703, val_loss=0.6629
# Epoch 517/700: train_loss=0.1742, val_loss=0.6639
# Epoch 518/700: train_loss=0.1725, val_loss=0.6620
# Epoch 519/700: train_loss=0.1688, val_loss=0.6588
# Epoch 520/700: train_loss=0.1700, val_loss=0.6630
# Epoch 521/700: train_loss=0.1704, val_loss=0.6611
# Epoch 522/700: train_loss=0.1747, val_loss=0.6630
# Epoch 523/700: train_loss=0.1677, val_loss=0.6635
# Epoch 524/700: train_loss=0.1750, val_loss=0.6683
# Epoch 525/700: train_loss=0.1705, val_loss=0.6613
# Epoch 526/700: train_loss=0.1730, val_loss=0.6648
# Epoch 527/700: train_loss=0.1678, val_loss=0.6601
# Epoch 528/700: train_loss=0.1676, val_loss=0.6603
# Epoch 529/700: train_loss=0.1755, val_loss=0.6659
# Epoch 530/700: train_loss=0.1680, val_loss=0.6603
# Epoch 531/700: train_loss=0.1732, val_loss=0.6649
# Epoch 532/700: train_loss=0.1754, val_loss=0.6656
# Epoch 533/700: train_loss=0.1722, val_loss=0.6629
# Epoch 534/700: train_loss=0.1707, val_loss=0.6635
# Epoch 535/700: train_loss=0.1664, val_loss=0.6605
# Epoch 536/700: train_loss=0.1682, val_loss=0.6635
# Epoch 537/700: train_loss=0.1702, val_loss=0.6625
# Epoch 538/700: train_loss=0.1649, val_loss=0.6616
# Epoch 539/700: train_loss=0.1666, val_loss=0.6612
# Epoch 540/700: train_loss=0.1693, val_loss=0.6646
# Epoch 541/700: train_loss=0.1722, val_loss=0.6644
# Epoch 542/700: train_loss=0.1711, val_loss=0.6636
# Epoch 543/700: train_loss=0.1728, val_loss=0.6644
# Epoch 544/700: train_loss=0.1689, val_loss=0.6635
# Epoch 545/700: train_loss=0.1678, val_loss=0.6618
# Epoch 546/700: train_loss=0.1649, val_loss=0.6619
# Epoch 547/700: train_loss=0.1675, val_loss=0.6612
# Epoch 548/700: train_loss=0.1667, val_loss=0.6605
# Epoch 549/700: train_loss=0.1690, val_loss=0.6626
# Epoch 550/700: train_loss=0.1659, val_loss=0.6617
# Epoch 551/700: train_loss=0.1704, val_loss=0.6630
# Epoch 552/700: train_loss=0.1706, val_loss=0.6623
# Epoch 553/700: train_loss=0.1677, val_loss=0.6611
# Epoch 554/700: train_loss=0.1708, val_loss=0.6654
# Epoch 555/700: train_loss=0.1704, val_loss=0.6621
# Epoch 556/700: train_loss=0.1668, val_loss=0.6625
# Epoch 557/700: train_loss=0.1682, val_loss=0.6624
# Epoch 558/700: train_loss=0.1714, val_loss=0.6646
# Epoch 559/700: train_loss=0.1719, val_loss=0.6633
# Epoch 560/700: train_loss=0.1667, val_loss=0.6626
# Epoch 561/700: train_loss=0.1709, val_loss=0.6645
# Epoch 562/700: train_loss=0.1712, val_loss=0.6642
# Epoch 563/700: train_loss=0.1637, val_loss=0.6606
# Epoch 564/700: train_loss=0.1668, val_loss=0.6620
# Epoch 565/700: train_loss=0.1702, val_loss=0.6647
# Epoch 566/700: train_loss=0.1668, val_loss=0.6636
# Epoch 567/700: train_loss=0.1718, val_loss=0.6644
# Epoch 568/700: train_loss=0.1679, val_loss=0.6625
# Epoch 569/700: train_loss=0.1713, val_loss=0.6646
# Epoch 570/700: train_loss=0.1698, val_loss=0.6643
# Epoch 571/700: train_loss=0.1688, val_loss=0.6623
# Epoch 572/700: train_loss=0.1669, val_loss=0.6627
# Epoch 573/700: train_loss=0.1714, val_loss=0.6644
# Epoch 574/700: train_loss=0.1678, val_loss=0.6637
# Epoch 575/700: train_loss=0.1703, val_loss=0.6644
# Epoch 576/700: train_loss=0.1707, val_loss=0.6657
# Epoch 577/700: train_loss=0.1692, val_loss=0.6633
# Epoch 578/700: train_loss=0.1670, val_loss=0.6628
# Epoch 579/700: train_loss=0.1751, val_loss=0.6685
# Epoch 580/700: train_loss=0.1705, val_loss=0.6651
# Epoch 581/700: train_loss=0.1703, val_loss=0.6639
# Epoch 582/700: train_loss=0.1682, val_loss=0.6621
# Epoch 583/700: train_loss=0.1699, val_loss=0.6651
# Epoch 584/700: train_loss=0.1692, val_loss=0.6650
# Epoch 585/700: train_loss=0.1664, val_loss=0.6625
# Epoch 586/700: train_loss=0.1691, val_loss=0.6642
# Epoch 587/700: train_loss=0.1707, val_loss=0.6659
# Epoch 588/700: train_loss=0.1681, val_loss=0.6626
# Epoch 589/700: train_loss=0.1700, val_loss=0.6673
# Epoch 590/700: train_loss=0.1668, val_loss=0.6631
# Epoch 591/700: train_loss=0.1707, val_loss=0.6653
# Epoch 592/700: train_loss=0.1655, val_loss=0.6623
# Epoch 593/700: train_loss=0.1691, val_loss=0.6657
# Epoch 594/700: train_loss=0.1659, val_loss=0.6626
# Epoch 595/700: train_loss=0.1702, val_loss=0.6660
# Epoch 596/700: train_loss=0.1688, val_loss=0.6650
# Epoch 597/700: train_loss=0.1652, val_loss=0.6628
# Epoch 598/700: train_loss=0.1693, val_loss=0.6654
# Epoch 599/700: train_loss=0.1694, val_loss=0.6647
# Epoch 600/700: train_loss=0.1664, val_loss=0.6625
# Epoch 601/700: train_loss=0.1659, val_loss=0.6642
# Epoch 602/700: train_loss=0.1647, val_loss=0.6629
# Epoch 603/700: train_loss=0.1703, val_loss=0.6676
# Epoch 604/700: train_loss=0.1639, val_loss=0.6623
# Epoch 605/700: train_loss=0.1723, val_loss=0.6674
# Epoch 606/700: train_loss=0.1642, val_loss=0.6639
# Epoch 607/700: train_loss=0.1663, val_loss=0.6636
# Epoch 608/700: train_loss=0.1654, val_loss=0.6640
# Epoch 609/700: train_loss=0.1654, val_loss=0.6630
# Epoch 610/700: train_loss=0.1666, val_loss=0.6633
# Epoch 611/700: train_loss=0.1667, val_loss=0.6632
# Epoch 612/700: train_loss=0.1717, val_loss=0.6674
# Epoch 613/700: train_loss=0.1647, val_loss=0.6631
# Epoch 614/700: train_loss=0.1716, val_loss=0.6663
# Epoch 615/700: train_loss=0.1656, val_loss=0.6634
# Epoch 616/700: train_loss=0.1668, val_loss=0.6651
# Epoch 617/700: train_loss=0.1627, val_loss=0.6622
# Epoch 618/700: train_loss=0.1689, val_loss=0.6648
# Epoch 619/700: train_loss=0.1654, val_loss=0.6646
# Epoch 620/700: train_loss=0.1701, val_loss=0.6669
# Epoch 621/700: train_loss=0.1701, val_loss=0.6677
# Epoch 622/700: train_loss=0.1644, val_loss=0.6637
# Epoch 623/700: train_loss=0.1642, val_loss=0.6626
# Epoch 624/700: train_loss=0.1656, val_loss=0.6644
# Epoch 625/700: train_loss=0.1696, val_loss=0.6661
# Epoch 626/700: train_loss=0.1698, val_loss=0.6680
# Epoch 627/700: train_loss=0.1680, val_loss=0.6655
# Epoch 628/700: train_loss=0.1691, val_loss=0.6661
# Epoch 629/700: train_loss=0.1655, val_loss=0.6647
# Epoch 630/700: train_loss=0.1684, val_loss=0.6653
# Epoch 631/700: train_loss=0.1700, val_loss=0.6679
# Epoch 632/700: train_loss=0.1650, val_loss=0.6638
# Epoch 633/700: train_loss=0.1706, val_loss=0.6673
# Epoch 634/700: train_loss=0.1681, val_loss=0.6672
# Epoch 635/700: train_loss=0.1682, val_loss=0.6668
# Epoch 636/700: train_loss=0.1674, val_loss=0.6669
# Epoch 637/700: train_loss=0.1663, val_loss=0.6646
# Epoch 638/700: train_loss=0.1654, val_loss=0.6643
# Epoch 639/700: train_loss=0.1661, val_loss=0.6651
# Epoch 640/700: train_loss=0.1639, val_loss=0.6643
# Epoch 641/700: train_loss=0.1676, val_loss=0.6657
# Epoch 642/700: train_loss=0.1630, val_loss=0.6630
# Epoch 643/700: train_loss=0.1650, val_loss=0.6640
# Epoch 644/700: train_loss=0.1641, val_loss=0.6645
# Epoch 645/700: train_loss=0.1620, val_loss=0.6627
# Epoch 646/700: train_loss=0.1688, val_loss=0.6657
# Epoch 647/700: train_loss=0.1633, val_loss=0.6630
# Epoch 648/700: train_loss=0.1654, val_loss=0.6653
# Epoch 649/700: train_loss=0.1646, val_loss=0.6639
# Epoch 650/700: train_loss=0.1660, val_loss=0.6646
# Epoch 651/700: train_loss=0.1700, val_loss=0.6680
# Epoch 652/700: train_loss=0.1665, val_loss=0.6656
# Epoch 653/700: train_loss=0.1649, val_loss=0.6637
# Epoch 654/700: train_loss=0.1685, val_loss=0.6674
# Epoch 655/700: train_loss=0.1627, val_loss=0.6650
# Epoch 656/700: train_loss=0.1646, val_loss=0.6642
# Epoch 657/700: train_loss=0.1639, val_loss=0.6647
# Epoch 658/700: train_loss=0.1695, val_loss=0.6686
# Epoch 659/700: train_loss=0.1671, val_loss=0.6665
# Epoch 660/700: train_loss=0.1619, val_loss=0.6631
# Epoch 661/700: train_loss=0.1644, val_loss=0.6647
# Epoch 662/700: train_loss=0.1666, val_loss=0.6656
# Epoch 663/700: train_loss=0.1684, val_loss=0.6670
# Epoch 664/700: train_loss=0.1644, val_loss=0.6640
# Epoch 665/700: train_loss=0.1662, val_loss=0.6660
# Epoch 666/700: train_loss=0.1627, val_loss=0.6628
# Epoch 667/700: train_loss=0.1693, val_loss=0.6676
# Epoch 668/700: train_loss=0.1627, val_loss=0.6642
# Epoch 669/700: train_loss=0.1680, val_loss=0.6674
# Epoch 670/700: train_loss=0.1652, val_loss=0.6651
# Epoch 671/700: train_loss=0.1695, val_loss=0.6689
# Epoch 672/700: train_loss=0.1646, val_loss=0.6648
# Epoch 673/700: train_loss=0.1660, val_loss=0.6654
# Epoch 674/700: train_loss=0.1629, val_loss=0.6635
# Epoch 675/700: train_loss=0.1662, val_loss=0.6674
# Epoch 676/700: train_loss=0.1630, val_loss=0.6641
# Epoch 677/700: train_loss=0.1632, val_loss=0.6645
# Epoch 678/700: train_loss=0.1692, val_loss=0.6668
# Epoch 679/700: train_loss=0.1651, val_loss=0.6650
# Epoch 680/700: train_loss=0.1665, val_loss=0.6667
# Epoch 681/700: train_loss=0.1641, val_loss=0.6641
# Epoch 682/700: train_loss=0.1649, val_loss=0.6652
# Epoch 683/700: train_loss=0.1654, val_loss=0.6646
# Epoch 684/700: train_loss=0.1627, val_loss=0.6631
# Epoch 685/700: train_loss=0.1650, val_loss=0.6654
# Epoch 686/700: train_loss=0.1667, val_loss=0.6657
# Epoch 687/700: train_loss=0.1628, val_loss=0.6638
# Epoch 688/700: train_loss=0.1686, val_loss=0.6682
# Epoch 689/700: train_loss=0.1665, val_loss=0.6660
# Epoch 690/700: train_loss=0.1622, val_loss=0.6649
# Epoch 691/700: train_loss=0.1665, val_loss=0.6659
# Epoch 692/700: train_loss=0.1630, val_loss=0.6645
# Epoch 693/700: train_loss=0.1671, val_loss=0.6661
# Epoch 694/700: train_loss=0.1640, val_loss=0.6645
# Epoch 695/700: train_loss=0.1668, val_loss=0.6665
# Epoch 696/700: train_loss=0.1666, val_loss=0.6661
# Epoch 697/700: train_loss=0.1640, val_loss=0.6659
# Epoch 698/700: train_loss=0.1648, val_loss=0.6654
# Epoch 699/700: train_loss=0.1652, val_loss=0.6662
# Epoch 700/700: train_loss=0.1654, val_loss=0.6666

# %% [markdown]
# Let us try to observe the trend of the training and validation losses. Going down together is better!

# %%
import matplotlib.pyplot as plt

plt.plot(range(epochs), history['train_losses'], label='train_loss')
plt.plot(range(epochs), history['val_losses'], label='val_loss')
plt.plot(history['best_epoch'], history['val_losses'][history['best_epoch']], marker='*')
plt.legend()
plt.show()

# %% [markdown]
# **Warning**: The common mistake with programmers is that they forgot to save the model at the best validation loss (minimum val_loss). The `history` variable tracks the best model.

# %% [markdown]
# Now, let us try to validate our model using the validation set. Notice that we use the `X_val` and `y_val`.

# %%
from sklearn import metrics

best_model = history['best_model']
y_val_pred = best_model.predict(X_val)
print(f"{metrics.classification_report(y_val, y_val_pred)}")
metrics.ConfusionMatrixDisplay.from_predictions(y_val, y_val_pred)
# Out:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.56      0.42      0.48        12
#      Colin Powell       0.79      0.86      0.82        35
#   Donald Rumsfeld       0.72      0.72      0.72        18
#     George W Bush       0.88      0.97      0.92        79
# Gerhard Schroeder       0.62      0.59      0.61        17
#       Hugo Chavez       0.71      0.45      0.56        11
#        Tony Blair       0.76      0.62      0.68        21
#
#          accuracy                           0.79       193
#         macro avg       0.72      0.66      0.68       193
#      weighted avg       0.78      0.79      0.78       193

# %% [markdown]
# ## 3. Testing
#
# Let us evaluate our best model using the testing set `X_test` and `y_test`.

# %%
y_test_pred = best_model.predict(X_test)
print(f"{metrics.classification_report(y_test, y_test_pred)}")
metrics.ConfusionMatrixDisplay.from_predictions(y_test, y_test_pred)
# Out:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.62      0.73      0.67        11
#      Colin Powell       0.81      0.81      0.81        36
#   Donald Rumsfeld       0.71      0.53      0.61        19
#     George W Bush       0.83      0.93      0.88        80
# Gerhard Schroeder       0.86      0.75      0.80        16
#       Hugo Chavez       0.89      0.80      0.84        10
#        Tony Blair       0.84      0.73      0.78        22
#
#          accuracy                           0.81       194
#         macro avg       0.79      0.75      0.77       194
#      weighted avg       0.81      0.81      0.81       194

# %% [markdown]
# Note: Do not forget to save your model offline.

# %%
import joblib

joblib.dump(best_model, 'mlp_model_e3.pkl')
# Out:
# ['mlp_model_e3.pkl']

# %% [markdown]
# ## 4. Deployment
#
# When deploying your system, you are not required to re-run the training, but you just need to run feedforward prediction using the saved model.

# %%
import joblib
import numpy as np

# Load trained model
loaded_model = joblib.load('mlp_model_e3.pkl')

# New sample (8x8 = 64 features)
x_new = [
    0,  0,  0,  5,  9,  0,  0,  0,
    0,  0,  2, 14, 14, 22,  0,  0,
    0,  0,  6, 14, 11,  9,  0,  0,
    0,  3, 15,  3, 11,  5,  0,  0,
    0,  8, 11,  0, 13,  6,  2,  0,
    6, 10, 16, 16, 12, 15, 17,  0,
    0,  0,  4, 10, 15,  3,  0,  0,
    0,  0,  0, 11, 13,  2,  0,  0
]

# Convert to numpy array
x_new = np.array(x_new).reshape(1, -1)   # shape = (1, 64)

# --- Fix shape mismatch ---
# Pad with zeros to match the model's expected number of features
expected_features = loaded_model.n_features_in_
if x_new.shape[1] < expected_features:
    # Pad zeros on the right
    x_new = np.pad(x_new, ((0, 0), (0, expected_features - x_new.shape[1])), mode='constant')

elif x_new.shape[1] > expected_features:
    # Trim extra features if too many
    x_new = x_new[:, :expected_features]

# Predict
y_new_pred = loaded_model.predict(x_new)
print(f"Predicted digit = {y_new_pred[0]}")
# Out:
# Predicted digit = Hugo Chavez
# c:\Users\DWIGHT LANCE JUMAOAS\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but PassiveAggressiveClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# **Challenge**: Try to run this [Python script](https://drive.google.com/file/d/1TkXU8jfWE03bb_N2AUL5_C9Y_vM1Kj7q/view?usp=drive_link) in offline mode, not here in Google Colab. Note that the file is the Python script from Laboratory 2. However, make sure to place both Python script and trained model (`mlp_model_e3.pkl`) in the same directory. Also, change the line that loads the model, overwrite with `mlp_model_e3.pkl`.

# %%
# End of laboratory notebook. Nothing follows ...
