# %% [markdown]
# # Machine Learning Workflow: Batch Processing
#
# Let us climb up to our learning curve by understanding the impact of batch processing to the ML workflow. Recall that in the previous laboratory notebook, we train our model at once on the training set. In reality, if you have a very large dataset, you need to employ batch processing. The training set is being divided into batches. The illustration below shows the changes of the ML workflow, applying the batch processing concept.
#
# By the end of this laboratory notebook, you will be able to **apply batch processing in any ML classification task.**

# %% [markdown]
# ![workflow2.png](data:image/png;base64,...)

# %% [markdown]
# ## 1. Data Preparation
# We will use again the MNIST dataset as our `raw data`.

# %% [markdown]
# Recall that you can download the `mnist_digits.csv` from this [GDrive](https://drive.google.com/file/d/1eAmVYcpRvkYM7MXb7vTu95zQjWjS1iet/view?usp=sharing).

# %%
import pandas as pd

try: # if csv file is already in Colab, then load
  raw_data = pd.read_csv("C:/Users/DWIGHT LANCE JUMAOAS/don't open this/emerging_technology/emerging-technologies-main/activities/machine_learning_samples/lfw_people.csv")
  print("Loaded lfw_people.csv into a DataFrame.")
except FileNotFoundError: # otherwise, allow user to upload the CSV file
  uploaded = files.upload()
  for filename in uploaded.keys():
      raw_data = pd.read_csv(filename)
      print(f"Loaded {filename} into a DataFrame.")
# Out:
# Loaded lfw_people.csv into a DataFrame.

# %% [markdown]
# There will be no changes when preparing the dataset. So, our next move is to determine the `features` and `ground-truth classes`. Once again, we will represent the array of features as the `X` variable, while the ground-truth classes (or the targets) as the `y` variable.

# %%
X = raw_data.iloc[:, :-1]
y = raw_data.iloc[:, -1]

# %% [markdown]
# Likewise we will perform data splitting: 70% training, 15% validation, and 15% testing.

# %%
from sklearn.model_selection import train_test_split

X_train, X_others, y_train, y_others = train_test_split(
    X, # features
    y, # targets
    train_size=0.7, # 70% training set
    stratify=y, # split according to even distribution of targets
    shuffle=True
)

X_val, X_test, y_val, y_test = train_test_split(
    X_others, # features
    y_others, # targets
    test_size = 0.5, # 15% = 0.5 of 30%
    stratify=y_others, # split according to even distribution of targets
    shuffle=True
)

# %% [markdown]
# Alright! So now, you need to remember that:
#
#
# 1.   `X_train` and `y_train` correspond to the features and targets in the training set.
# 2.   `X_val` and `y_val` correspond to the features and targets in the validation set.
# 3.   `X_test` and `y_test` correspond to the features and targets in the training set.

# %% [markdown]
# ## 2. Training
#
# In this laboratory notebook,we will utilize again the same algorithm, which is the ANN-MLP. We also retain the number of hidden layers and the number of hidden nodes. However, we introduce two new things:
#
#
# 1.   Epoch and batch size
# 2.   Categorical cross-entropy loss

# %%
from sklearn.linear_model import PassiveAggressiveClassifier

# Initialize model
model = PassiveAggressiveClassifier(
    max_iter=1000, 
    C=1,          
    loss="squared_hinge"  
)

# %% [markdown]
# Before we go for training, we need to learn first what are `epoch` and `batch size`.
#
#
# *   `epoch`: refers to one complete pass through the entire training dataset.
# *   `batch_size`: defines the number of samples that are used to update the model's parameters at each step during training.

# %%
epochs = 500
batch_size = 64

# %% [markdown]
# Since we will try to learn by batch size, let us create a function that create batches.

# %%
def get_batches(X, y, batch_size):
    for i in range(0, X.shape[0], batch_size):
        X_batch = X[i:i + batch_size]
        y_batch = y[i:i + batch_size]
        yield X_batch, y_batch

# %% [markdown]
# Also since what we want to do is a multiclass classification, we need to use the `categorical cross-entropy loss`. It is mathematically defined as:
#
# $ Loss = - \sum^{N}_{i=1} \sum^{C}_{c=1} y_{ic} log(p_{ic})$
#
# where,
# * $C$ is the number of classes (here, is 10)
# * $y_{ic}$ is the binary indicator (0 or 1) if class label $c$ is the correct classification for observation $i$
# * $p_{ic}$ is the predicted probability of observation $i$ being of class $c$
#
# But, no need to worry! Because we can call `log_loss` from scikit-learn to compute this value.

# %%
from sklearn.metrics import log_loss

# %% [markdown]
# Now, we begin the training of the model over multiple epochs with batch processing.

# %%
import numpy as np
import copy

history = {'train_losses': [], 'val_losses': [], 'best_model': None, 'best_epoch': 0}
classes = np.unique(y)

for epoch in range(epochs):
    first_batch = True  # reset each epoch

    # Train in mini-batches
    for X_batch, y_batch in get_batches(X_train, y_train, batch_size):
        if first_batch:
            model.partial_fit(X_batch, y_batch, classes=classes)
            first_batch = False
        else:
            model.partial_fit(X_batch, y_batch)

    # --- Training loss ---
    if hasattr(model, "predict_proba"):
        y_train_proba = model.predict_proba(X_train)
    else:
        # fallback for hinge loss: use decision_function -> softmax approximation
        decision = model.decision_function(X_train)
        exp_scores = np.exp(decision - np.max(decision, axis=1, keepdims=True))
        y_train_proba = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)

    y_train_proba = np.clip(y_train_proba, 1e-15, 1 - 1e-15)
    train_loss = log_loss(y_train, y_train_proba)

    # --- Validation loss ---
    if hasattr(model, "predict_proba"):
        y_val_proba = model.predict_proba(X_val)
    else:
        decision = model.decision_function(X_val)
        exp_scores = np.exp(decision - np.max(decision, axis=1, keepdims=True))
        y_val_proba = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)

    y_val_proba = np.clip(y_val_proba, 1e-15, 1 - 1e-15)
    val_loss = log_loss(y_val, y_val_proba)

    print(f"Epoch {epoch+1}/{epochs}: train_loss={train_loss:.4f}, val_loss={val_loss:.4f}")

    # Save best model (deepcopy to freeze weights)
    if (history['best_model'] is None) or (val_loss < min(history['val_losses'], default=float("inf"))):
        history['best_model'] = copy.deepcopy(model)
        history['best_epoch'] = epoch

    history['train_losses'].append(train_loss)
    history['val_losses'].append(val_loss)
# Out:
# Epoch 1/500: train_loss=1.5523, val_loss=1.5938
# Epoch 2/500: train_loss=1.7844, val_loss=1.8129
# Epoch 3/500: train_loss=1.4778, val_loss=1.5426
# Epoch 4/500: train_loss=1.0636, val_loss=1.1660
# Epoch 5/500: train_loss=1.1043, val_loss=1.2155
# Epoch 6/500: train_loss=1.0359, val_loss=1.1649
# Epoch 7/500: train_loss=1.1043, val_loss=1.2265
# Epoch 8/500: train_loss=1.0070, val_loss=1.1415
# Epoch 9/500: train_loss=0.9118, val_loss=1.0651
# Epoch 10/500: train_loss=0.8891, val_loss=1.0415
# Epoch 11/500: train_loss=0.9269, val_loss=1.0959
# Epoch 12/500: train_loss=0.9403, val_loss=1.1000
# Epoch 13/500: train_loss=0.7839, val_loss=0.9631
# Epoch 14/500: train_loss=0.7638, val_loss=0.9584
# Epoch 15/500: train_loss=0.7957, val_loss=0.9916
# Epoch 16/500: train_loss=0.8454, val_loss=1.0321
# Epoch 17/500: train_loss=0.6990, val_loss=0.8995
# Epoch 18/500: train_loss=0.6918, val_loss=0.8948
# Epoch 19/500: train_loss=0.6750, val_loss=0.8842
# Epoch 20/500: train_loss=0.7467, val_loss=0.9549
# Epoch 21/500: train_loss=0.6593, val_loss=0.8862
# Epoch 22/500: train_loss=0.6434, val_loss=0.8734
# Epoch 23/500: train_loss=0.6125, val_loss=0.8480
# Epoch 24/500: train_loss=0.6173, val_loss=0.8534
# Epoch 25/500: train_loss=0.6432, val_loss=0.8755
# Epoch 26/500: train_loss=0.6607, val_loss=0.8918
# Epoch 27/500: train_loss=0.6709, val_loss=0.9037
# Epoch 28/500: train_loss=0.6251, val_loss=0.8673
# Epoch 29/500: train_loss=0.5660, val_loss=0.8135
# Epoch 30/500: train_loss=0.6059, val_loss=0.8529
# Epoch 31/500: train_loss=0.5543, val_loss=0.8083
# Epoch 32/500: train_loss=0.5844, val_loss=0.8375
# Epoch 33/500: train_loss=0.5372, val_loss=0.7963
# Epoch 34/500: train_loss=0.5411, val_loss=0.8018
# Epoch 35/500: train_loss=0.5220, val_loss=0.7879
# Epoch 36/500: train_loss=0.5076, val_loss=0.7774
# Epoch 37/500: train_loss=0.5551, val_loss=0.8172
# Epoch 38/500: train_loss=0.4952, val_loss=0.7687
# Epoch 39/500: train_loss=0.5063, val_loss=0.7810
# Epoch 40/500: train_loss=0.5196, val_loss=0.7887
# Epoch 41/500: train_loss=0.4763, val_loss=0.7548
# Epoch 42/500: train_loss=0.4824, val_loss=0.7581
# Epoch 43/500: train_loss=0.5040, val_loss=0.7857
# Epoch 44/500: train_loss=0.4636, val_loss=0.7520
# Epoch 45/500: train_loss=0.4422, val_loss=0.7324
# Epoch 46/500: train_loss=0.4570, val_loss=0.7496
# Epoch 47/500: train_loss=0.4793, val_loss=0.7628
# Epoch 48/500: train_loss=0.4557, val_loss=0.7442
# Epoch 49/500: train_loss=0.4434, val_loss=0.7378
# Epoch 50/500: train_loss=0.4675, val_loss=0.7610
# Epoch 51/500: train_loss=0.4561, val_loss=0.7497
# Epoch 52/500: train_loss=0.4689, val_loss=0.7649
# Epoch 53/500: train_loss=0.4235, val_loss=0.7255
# Epoch 54/500: train_loss=0.4386, val_loss=0.7403
# Epoch 55/500: train_loss=0.4231, val_loss=0.7250
# Epoch 56/500: train_loss=0.4234, val_loss=0.7332
# Epoch 57/500: train_loss=0.4465, val_loss=0.7472
# Epoch 58/500: train_loss=0.4188, val_loss=0.7293
# Epoch 59/500: train_loss=0.4365, val_loss=0.7423
# Epoch 60/500: train_loss=0.4172, val_loss=0.7229
# Epoch 61/500: train_loss=0.3922, val_loss=0.7104
# Epoch 62/500: train_loss=0.3899, val_loss=0.7063
# Epoch 63/500: train_loss=0.3914, val_loss=0.7106
# Epoch 64/500: train_loss=0.3996, val_loss=0.7194
# Epoch 65/500: train_loss=0.3925, val_loss=0.7091
# Epoch 66/500: train_loss=0.3960, val_loss=0.7085
# Epoch 67/500: train_loss=0.3856, val_loss=0.7000
# Epoch 68/500: train_loss=0.3983, val_loss=0.7118
# Epoch 69/500: train_loss=0.3786, val_loss=0.6995
# Epoch 70/500: train_loss=0.3822, val_loss=0.7045
# Epoch 71/500: train_loss=0.3961, val_loss=0.7127
# Epoch 72/500: train_loss=0.3866, val_loss=0.7102
# Epoch 73/500: train_loss=0.3711, val_loss=0.6963
# Epoch 74/500: train_loss=0.3747, val_loss=0.6960
# Epoch 75/500: train_loss=0.3598, val_loss=0.6915
# Epoch 76/500: train_loss=0.3511, val_loss=0.6798
# Epoch 77/500: train_loss=0.3573, val_loss=0.6868
# Epoch 78/500: train_loss=0.3557, val_loss=0.6875
# Epoch 79/500: train_loss=0.3499, val_loss=0.6790
# Epoch 80/500: train_loss=0.3535, val_loss=0.6826
# Epoch 81/500: train_loss=0.3519, val_loss=0.6890
# Epoch 82/500: train_loss=0.3351, val_loss=0.6747
# Epoch 83/500: train_loss=0.3349, val_loss=0.6745
# Epoch 84/500: train_loss=0.3462, val_loss=0.6821
# Epoch 85/500: train_loss=0.3418, val_loss=0.6811
# Epoch 86/500: train_loss=0.3306, val_loss=0.6722
# Epoch 87/500: train_loss=0.3359, val_loss=0.6788
# Epoch 88/500: train_loss=0.3368, val_loss=0.6843
# Epoch 89/500: train_loss=0.3353, val_loss=0.6792
# Epoch 90/500: train_loss=0.3318, val_loss=0.6749
# Epoch 91/500: train_loss=0.3326, val_loss=0.6769
# Epoch 92/500: train_loss=0.3291, val_loss=0.6767
# Epoch 93/500: train_loss=0.3340, val_loss=0.6834
# Epoch 94/500: train_loss=0.3206, val_loss=0.6677
# Epoch 95/500: train_loss=0.3106, val_loss=0.6617
# Epoch 96/500: train_loss=0.3187, val_loss=0.6638
# Epoch 97/500: train_loss=0.3176, val_loss=0.6658
# Epoch 98/500: train_loss=0.3150, val_loss=0.6657
# Epoch 99/500: train_loss=0.3164, val_loss=0.6683
# Epoch 100/500: train_loss=0.3035, val_loss=0.6585
# Epoch 101/500: train_loss=0.3160, val_loss=0.6710
# Epoch 102/500: train_loss=0.3086, val_loss=0.6647
# Epoch 103/500: train_loss=0.3126, val_loss=0.6665
# Epoch 104/500: train_loss=0.3204, val_loss=0.6752
# Epoch 105/500: train_loss=0.3093, val_loss=0.6630
# Epoch 106/500: train_loss=0.3007, val_loss=0.6566
# Epoch 107/500: train_loss=0.3027, val_loss=0.6575
# Epoch 108/500: train_loss=0.3025, val_loss=0.6585
# Epoch 109/500: train_loss=0.2995, val_loss=0.6599
# Epoch 110/500: train_loss=0.2996, val_loss=0.6648
# Epoch 111/500: train_loss=0.3022, val_loss=0.6702
# Epoch 112/500: train_loss=0.2906, val_loss=0.6542
# Epoch 113/500: train_loss=0.2989, val_loss=0.6636
# Epoch 114/500: train_loss=0.2948, val_loss=0.6543
# Epoch 115/500: train_loss=0.2903, val_loss=0.6606
# Epoch 116/500: train_loss=0.2969, val_loss=0.6596
# Epoch 117/500: train_loss=0.3030, val_loss=0.6622
# Epoch 118/500: train_loss=0.2973, val_loss=0.6561
# Epoch 119/500: train_loss=0.2931, val_loss=0.6571
# Epoch 120/500: train_loss=0.2940, val_loss=0.6550
# Epoch 121/500: train_loss=0.2900, val_loss=0.6555
# Epoch 122/500: train_loss=0.2920, val_loss=0.6543
# Epoch 123/500: train_loss=0.2916, val_loss=0.6548
# Epoch 124/500: train_loss=0.3031, val_loss=0.6616
# Epoch 125/500: train_loss=0.2844, val_loss=0.6516
# Epoch 126/500: train_loss=0.2952, val_loss=0.6652
# Epoch 127/500: train_loss=0.3111, val_loss=0.6793
# Epoch 128/500: train_loss=0.2917, val_loss=0.6561
# Epoch 129/500: train_loss=0.2822, val_loss=0.6508
# Epoch 130/500: train_loss=0.2843, val_loss=0.6512
# Epoch 131/500: train_loss=0.3078, val_loss=0.6751
# Epoch 132/500: train_loss=0.2721, val_loss=0.6466
# Epoch 133/500: train_loss=0.2783, val_loss=0.6505
# Epoch 134/500: train_loss=0.2716, val_loss=0.6448
# Epoch 135/500: train_loss=0.2710, val_loss=0.6447
# Epoch 136/500: train_loss=0.2902, val_loss=0.6587
# Epoch 137/500: train_loss=0.2736, val_loss=0.6505
# Epoch 138/500: train_loss=0.2864, val_loss=0.6676
# Epoch 139/500: train_loss=0.2727, val_loss=0.6471
# Epoch 140/500: train_loss=0.2748, val_loss=0.6500
# Epoch 141/500: train_loss=0.2720, val_loss=0.6530
# Epoch 142/500: train_loss=0.2740, val_loss=0.6454
# Epoch 143/500: train_loss=0.2793, val_loss=0.6541
# Epoch 144/500: train_loss=0.2754, val_loss=0.6489
# Epoch 145/500: train_loss=0.2945, val_loss=0.6630
# Epoch 146/500: train_loss=0.2821, val_loss=0.6544
# Epoch 147/500: train_loss=0.2725, val_loss=0.6495
# Epoch 148/500: train_loss=0.2663, val_loss=0.6544
# Epoch 149/500: train_loss=0.2701, val_loss=0.6495
# Epoch 150/500: train_loss=0.2653, val_loss=0.6452
# Epoch 151/500: train_loss=0.2694, val_loss=0.6493
# Epoch 152/500: train_loss=0.2671, val_loss=0.6487
# Epoch 153/500: train_loss=0.2636, val_loss=0.6547
# Epoch 154/500: train_loss=0.2598, val_loss=0.6427
# Epoch 155/500: train_loss=0.2606, val_loss=0.6524
# Epoch 156/500: train_loss=0.2730, val_loss=0.6612
# Epoch 157/500: train_loss=0.2600, val_loss=0.6412
# Epoch 158/500: train_loss=0.2569, val_loss=0.6473
# Epoch 159/500: train_loss=0.2629, val_loss=0.6551
# Epoch 160/500: train_loss=0.2567, val_loss=0.6396
# Epoch 161/500: train_loss=0.2586, val_loss=0.6419
# Epoch 162/500: train_loss=0.2694, val_loss=0.6611
# Epoch 163/500: train_loss=0.2546, val_loss=0.6467
# Epoch 164/500: train_loss=0.2569, val_loss=0.6426
# Epoch 165/500: train_loss=0.2583, val_loss=0.6430
# Epoch 166/500: train_loss=0.2466, val_loss=0.6368
# Epoch 167/500: train_loss=0.2609, val_loss=0.6565
# Epoch 168/500: train_loss=0.2544, val_loss=0.6428
# Epoch 169/500: train_loss=0.2539, val_loss=0.6488
# Epoch 170/500: train_loss=0.2539, val_loss=0.6402
# Epoch 171/500: train_loss=0.2503, val_loss=0.6387
# Epoch 172/500: train_loss=0.2422, val_loss=0.6346
# Epoch 173/500: train_loss=0.2476, val_loss=0.6351
# Epoch 174/500: train_loss=0.2503, val_loss=0.6377
# Epoch 175/500: train_loss=0.2588, val_loss=0.6496
# Epoch 176/500: train_loss=0.2575, val_loss=0.6504
# Epoch 177/500: train_loss=0.2499, val_loss=0.6377
# Epoch 178/500: train_loss=0.2460, val_loss=0.6367
# Epoch 179/500: train_loss=0.2500, val_loss=0.6380
# Epoch 180/500: train_loss=0.2500, val_loss=0.6392
# Epoch 181/500: train_loss=0.2518, val_loss=0.6416
# Epoch 182/500: train_loss=0.2444, val_loss=0.6372
# Epoch 183/500: train_loss=0.2513, val_loss=0.6398
# Epoch 184/500: train_loss=0.2571, val_loss=0.6438
# Epoch 185/500: train_loss=0.2466, val_loss=0.6365
# Epoch 186/500: train_loss=0.2411, val_loss=0.6376
# Epoch 187/500: train_loss=0.2420, val_loss=0.6352
# Epoch 188/500: train_loss=0.2456, val_loss=0.6474
# Epoch 189/500: train_loss=0.2445, val_loss=0.6407
# Epoch 190/500: train_loss=0.2428, val_loss=0.6435
# Epoch 191/500: train_loss=0.2404, val_loss=0.6400
# Epoch 192/500: train_loss=0.2384, val_loss=0.6357
# Epoch 193/500: train_loss=0.2491, val_loss=0.6409
# Epoch 194/500: train_loss=0.2443, val_loss=0.6368
# Epoch 195/500: train_loss=0.2426, val_loss=0.6372
# Epoch 196/500: train_loss=0.2507, val_loss=0.6425
# Epoch 197/500: train_loss=0.2403, val_loss=0.6368
# Epoch 198/500: train_loss=0.2456, val_loss=0.6389
# Epoch 199/500: train_loss=0.2457, val_loss=0.6462
# Epoch 200/500: train_loss=0.2377, val_loss=0.6330
# Epoch 201/500: train_loss=0.2356, val_loss=0.6393
# Epoch 202/500: train_loss=0.2437, val_loss=0.6390
# Epoch 203/500: train_loss=0.2354, val_loss=0.6323
# Epoch 204/500: train_loss=0.2360, val_loss=0.6398
# Epoch 205/500: train_loss=0.2368, val_loss=0.6344
# Epoch 206/500: train_loss=0.2349, val_loss=0.6332
# Epoch 207/500: train_loss=0.2402, val_loss=0.6366
# Epoch 208/500: train_loss=0.2337, val_loss=0.6318
# Epoch 209/500: train_loss=0.2351, val_loss=0.6336
# Epoch 210/500: train_loss=0.2320, val_loss=0.6318
# Epoch 211/500: train_loss=0.2302, val_loss=0.6321
# Epoch 212/500: train_loss=0.2307, val_loss=0.6316
# Epoch 213/500: train_loss=0.2347, val_loss=0.6347
# Epoch 214/500: train_loss=0.2335, val_loss=0.6399
# Epoch 215/500: train_loss=0.2370, val_loss=0.6344
# Epoch 216/500: train_loss=0.2316, val_loss=0.6327
# Epoch 217/500: train_loss=0.2376, val_loss=0.6365
# Epoch 218/500: train_loss=0.2348, val_loss=0.6429
# Epoch 219/500: train_loss=0.2307, val_loss=0.6325
# Epoch 220/500: train_loss=0.2301, val_loss=0.6326
# Epoch 221/500: train_loss=0.2311, val_loss=0.6335
# Epoch 222/500: train_loss=0.2297, val_loss=0.6345
# Epoch 223/500: train_loss=0.2327, val_loss=0.6425
# Epoch 224/500: train_loss=0.2249, val_loss=0.6305
# Epoch 225/500: train_loss=0.2275, val_loss=0.6312
# Epoch 226/500: train_loss=0.2279, val_loss=0.6306
# Epoch 227/500: train_loss=0.2291, val_loss=0.6311
# Epoch 228/500: train_loss=0.2323, val_loss=0.6414
# Epoch 229/500: train_loss=0.2217, val_loss=0.6281
# Epoch 230/500: train_loss=0.2332, val_loss=0.6337
# Epoch 231/500: train_loss=0.2257, val_loss=0.6307
# Epoch 232/500: train_loss=0.2305, val_loss=0.6330
# Epoch 233/500: train_loss=0.2301, val_loss=0.6324
# Epoch 234/500: train_loss=0.2282, val_loss=0.6324
# Epoch 235/500: train_loss=0.2307, val_loss=0.6375
# Epoch 236/500: train_loss=0.2334, val_loss=0.6425
# Epoch 237/500: train_loss=0.2310, val_loss=0.6356
# Epoch 238/500: train_loss=0.2294, val_loss=0.6354
# Epoch 239/500: train_loss=0.2272, val_loss=0.6365
# Epoch 240/500: train_loss=0.2261, val_loss=0.6336
# Epoch 241/500: train_loss=0.2256, val_loss=0.6316
# Epoch 242/500: train_loss=0.2255, val_loss=0.6317
# Epoch 243/500: train_loss=0.2241, val_loss=0.6308
# Epoch 244/500: train_loss=0.2256, val_loss=0.6389
# Epoch 245/500: train_loss=0.2305, val_loss=0.6365
# Epoch 246/500: train_loss=0.2231, val_loss=0.6308
# Epoch 247/500: train_loss=0.2239, val_loss=0.6301
# Epoch 248/500: train_loss=0.2244, val_loss=0.6306
# Epoch 249/500: train_loss=0.2291, val_loss=0.6350
# Epoch 250/500: train_loss=0.2228, val_loss=0.6319
# Epoch 251/500: train_loss=0.2276, val_loss=0.6342
# Epoch 252/500: train_loss=0.2181, val_loss=0.6307
# Epoch 253/500: train_loss=0.2215, val_loss=0.6307
# Epoch 254/500: train_loss=0.2223, val_loss=0.6292
# Epoch 255/500: train_loss=0.2183, val_loss=0.6279
# Epoch 256/500: train_loss=0.2180, val_loss=0.6284
# Epoch 257/500: train_loss=0.2187, val_loss=0.6283
# Epoch 258/500: train_loss=0.2157, val_loss=0.6268
# Epoch 259/500: train_loss=0.2127, val_loss=0.6267
# Epoch 260/500: train_loss=0.2153, val_loss=0.6270
# Epoch 261/500: train_loss=0.2156, val_loss=0.6274
# Epoch 262/500: train_loss=0.2161, val_loss=0.6282
# Epoch 263/500: train_loss=0.2202, val_loss=0.6294
# Epoch 264/500: train_loss=0.2150, val_loss=0.6270
# Epoch 265/500: train_loss=0.2154, val_loss=0.6266
# Epoch 266/500: train_loss=0.2150, val_loss=0.6269
# Epoch 267/500: train_loss=0.2184, val_loss=0.6296
# Epoch 268/500: train_loss=0.2220, val_loss=0.6333
# Epoch 269/500: train_loss=0.2164, val_loss=0.6302
# Epoch 270/500: train_loss=0.2148, val_loss=0.6321
# Epoch 271/500: train_loss=0.2146, val_loss=0.6301
# Epoch 272/500: train_loss=0.2144, val_loss=0.6300
# Epoch 273/500: train_loss=0.2158, val_loss=0.6294
# Epoch 274/500: train_loss=0.2101, val_loss=0.6267
# Epoch 275/500: train_loss=0.2126, val_loss=0.6267
# Epoch 276/500: train_loss=0.2240, val_loss=0.6328
# Epoch 277/500: train_loss=0.2169, val_loss=0.6300
# Epoch 278/500: train_loss=0.2174, val_loss=0.6282
# Epoch 279/500: train_loss=0.2128, val_loss=0.6246
# Epoch 280/500: train_loss=0.2137, val_loss=0.6281
# Epoch 281/500: train_loss=0.2091, val_loss=0.6241
# Epoch 282/500: train_loss=0.2160, val_loss=0.6314
# Epoch 283/500: train_loss=0.2120, val_loss=0.6268
# Epoch 284/500: train_loss=0.2096, val_loss=0.6247
# Epoch 285/500: train_loss=0.2123, val_loss=0.6270
# Epoch 286/500: train_loss=0.2113, val_loss=0.6260
# Epoch 287/500: train_loss=0.2189, val_loss=0.6305
# Epoch 288/500: train_loss=0.2147, val_loss=0.6320
# Epoch 289/500: train_loss=0.2123, val_loss=0.6265
# Epoch 290/500: train_loss=0.2118, val_loss=0.6307
# Epoch 291/500: train_loss=0.2127, val_loss=0.6313
# Epoch 292/500: train_loss=0.2116, val_loss=0.6308
# Epoch 293/500: train_loss=0.2082, val_loss=0.6259
# Epoch 294/500: train_loss=0.2066, val_loss=0.6225
# Epoch 295/500: train_loss=0.2099, val_loss=0.6252
# Epoch 296/500: train_loss=0.2086, val_loss=0.6259
# Epoch 297/500: train_loss=0.2120, val_loss=0.6315
# Epoch 298/500: train_loss=0.2108, val_loss=0.6256
# Epoch 299/500: train_loss=0.2136, val_loss=0.6308
# Epoch 300/500: train_loss=0.2072, val_loss=0.6241
# Epoch 301/500: train_loss=0.2131, val_loss=0.6276
# Epoch 302/500: train_loss=0.2123, val_loss=0.6278
# Epoch 303/500: train_loss=0.2131, val_loss=0.6273
# Epoch 304/500: train_loss=0.2137, val_loss=0.6285
# Epoch 305/500: train_loss=0.2138, val_loss=0.6285
# Epoch 306/500: train_loss=0.2099, val_loss=0.6262
# Epoch 307/500: train_loss=0.2113, val_loss=0.6282
# Epoch 308/500: train_loss=0.2076, val_loss=0.6262
# Epoch 309/500: train_loss=0.2094, val_loss=0.6272
# Epoch 310/500: train_loss=0.2067, val_loss=0.6262
# Epoch 311/500: train_loss=0.2075, val_loss=0.6289
# Epoch 312/500: train_loss=0.2081, val_loss=0.6267
# Epoch 313/500: train_loss=0.2054, val_loss=0.6261
# Epoch 314/500: train_loss=0.2057, val_loss=0.6278
# Epoch 315/500: train_loss=0.2049, val_loss=0.6261
# Epoch 316/500: train_loss=0.2085, val_loss=0.6274
# Epoch 317/500: train_loss=0.2103, val_loss=0.6298
# Epoch 318/500: train_loss=0.2051, val_loss=0.6262
# Epoch 319/500: train_loss=0.2076, val_loss=0.6278
# Epoch 320/500: train_loss=0.2060, val_loss=0.6281
# Epoch 321/500: train_loss=0.2115, val_loss=0.6299
# Epoch 322/500: train_loss=0.2112, val_loss=0.6290
# Epoch 323/500: train_loss=0.2086, val_loss=0.6316
# Epoch 324/500: train_loss=0.2095, val_loss=0.6288
# Epoch 325/500: train_loss=0.2088, val_loss=0.6285
# Epoch 326/500: train_loss=0.2068, val_loss=0.6263
# Epoch 327/500: train_loss=0.2068, val_loss=0.6251
# Epoch 328/500: train_loss=0.2081, val_loss=0.6267
# Epoch 329/500: train_loss=0.2083, val_loss=0.6267
# Epoch 330/500: train_loss=0.2049, val_loss=0.6274
# Epoch 331/500: train_loss=0.2072, val_loss=0.6285
# Epoch 332/500: train_loss=0.2093, val_loss=0.6269
# Epoch 333/500: train_loss=0.2091, val_loss=0.6269
# Epoch 334/500: train_loss=0.2075, val_loss=0.6263
# Epoch 335/500: train_loss=0.2079, val_loss=0.6265
# Epoch 336/500: train_loss=0.2076, val_loss=0.6264
# Epoch 337/500: train_loss=0.2056, val_loss=0.6250
# Epoch 338/500: train_loss=0.2046, val_loss=0.6240
# Epoch 339/500: train_loss=0.2082, val_loss=0.6266
# Epoch 340/500: train_loss=0.2046, val_loss=0.6242
# Epoch 341/500: train_loss=0.2056, val_loss=0.6248
# Epoch 342/500: train_loss=0.2059, val_loss=0.6250
# Epoch 343/500: train_loss=0.2099, val_loss=0.6281
# Epoch 344/500: train_loss=0.2066, val_loss=0.6287
# Epoch 345/500: train_loss=0.2040, val_loss=0.6248
# Epoch 346/500: train_loss=0.2066, val_loss=0.6263
# Epoch 347/500: train_loss=0.2056, val_loss=0.6257
# Epoch 348/500: train_loss=0.2050, val_loss=0.6265
# Epoch 349/500: train_loss=0.2025, val_loss=0.6236
# Epoch 350/500: train_loss=0.2030, val_loss=0.6230
# Epoch 351/500: train_loss=0.2073, val_loss=0.6292
# Epoch 352/500: train_loss=0.2075, val_loss=0.6279
# Epoch 353/500: train_loss=0.2038, val_loss=0.6247
# Epoch 354/500: train_loss=0.2066, val_loss=0.6256
# Epoch 355/500: train_loss=0.2074, val_loss=0.6266
# Epoch 356/500: train_loss=0.2032, val_loss=0.6257
# Epoch 357/500: train_loss=0.2056, val_loss=0.6265
# Epoch 358/500: train_loss=0.2081, val_loss=0.6282
# Epoch 359/500: train_loss=0.2075, val_loss=0.6266
# Epoch 360/500: train_loss=0.2067, val_loss=0.6253
# Epoch 361/500: train_loss=0.2067, val_loss=0.6253
# Epoch 362/500: train_loss=0.2030, val_loss=0.6250
# Epoch 363/500: train_loss=0.2027, val_loss=0.6270
# Epoch 364/500: train_loss=0.2043, val_loss=0.6249
# Epoch 365/500: train_loss=0.2050, val_loss=0.6251
# Epoch 366/500: train_loss=0.2008, val_loss=0.6250
# Epoch 367/500: train_loss=0.2001, val_loss=0.6238
# Epoch 368/500: train_loss=0.2026, val_loss=0.6274
# Epoch 369/500: train_loss=0.2024, val_loss=0.6269
# Epoch 370/500: train_loss=0.1996, val_loss=0.6243
# Epoch 371/500: train_loss=0.2029, val_loss=0.6249
# Epoch 372/500: train_loss=0.2022, val_loss=0.6242
# Epoch 373/500: train_loss=0.2013, val_loss=0.6239
# Epoch 374/500: train_loss=0.2016, val_loss=0.6236
# Epoch 375/500: train_loss=0.2011, val_loss=0.6231
# Epoch 376/500: train_loss=0.2013, val_loss=0.6229
# Epoch 377/500: train_loss=0.2065, val_loss=0.6258
# Epoch 378/500: train_loss=0.2026, val_loss=0.6244
# Epoch 379/500: train_loss=0.2040, val_loss=0.6252
# Epoch 380/500: train_loss=0.2023, val_loss=0.6234
# Epoch 381/500: train_loss=0.2016, val_loss=0.6246
# Epoch 382/500: train_loss=0.2030, val_loss=0.6266
# Epoch 383/500: train_loss=0.2023, val_loss=0.6246
# Epoch 384/500: train_loss=0.2033, val_loss=0.6258
# Epoch 385/500: train_loss=0.2040, val_loss=0.6243
# Epoch 386/500: train_loss=0.2053, val_loss=0.6250
# Epoch 387/500: train_loss=0.2058, val_loss=0.6255
# Epoch 388/500: train_loss=0.2020, val_loss=0.6240
# Epoch 389/500: train_loss=0.2019, val_loss=0.6241
# Epoch 390/500: train_loss=0.2003, val_loss=0.6227
# Epoch 391/500: train_loss=0.1990, val_loss=0.6220
# Epoch 392/500: train_loss=0.1994, val_loss=0.6243
# Epoch 393/500: train_loss=0.1987, val_loss=0.6225
# Epoch 394/500: train_loss=0.2040, val_loss=0.6254
# Epoch 395/500: train_loss=0.2039, val_loss=0.6267
# Epoch 396/500: train_loss=0.2043, val_loss=0.6265
# Epoch 397/500: train_loss=0.2026, val_loss=0.6256
# Epoch 398/500: train_loss=0.2030, val_loss=0.6262
# Epoch 399/500: train_loss=0.2019, val_loss=0.6258
# Epoch 400/500: train_loss=0.1989, val_loss=0.6244
# Epoch 401/500: train_loss=0.2062, val_loss=0.6293
# Epoch 402/500: train_loss=0.2033, val_loss=0.6267
# Epoch 403/500: train_loss=0.2013, val_loss=0.6259
# Epoch 404/500: train_loss=0.1986, val_loss=0.6242
# Epoch 405/500: train_loss=0.2025, val_loss=0.6272
# Epoch 406/500: train_loss=0.1997, val_loss=0.6235
# Epoch 407/500: train_loss=0.1976, val_loss=0.6223
# Epoch 408/500: train_loss=0.1948, val_loss=0.6226
# Epoch 409/500: train_loss=0.1954, val_loss=0.6212
# Epoch 410/500: train_loss=0.2001, val_loss=0.6241
# Epoch 411/500: train_loss=0.1990, val_loss=0.6252
# Epoch 412/500: train_loss=0.1987, val_loss=0.6250
# Epoch 413/500: train_loss=0.1966, val_loss=0.6225
# Epoch 414/500: train_loss=0.1959, val_loss=0.6227
# Epoch 415/500: train_loss=0.1956, val_loss=0.6227
# Epoch 416/500: train_loss=0.1934, val_loss=0.6205
# Epoch 417/500: train_loss=0.1951, val_loss=0.6216
# Epoch 418/500: train_loss=0.1959, val_loss=0.6238
# Epoch 419/500: train_loss=0.1983, val_loss=0.6245
# Epoch 420/500: train_loss=0.1993, val_loss=0.6230
# Epoch 421/500: train_loss=0.1957, val_loss=0.6230
# Epoch 422/500: train_loss=0.1942, val_loss=0.6225
# Epoch 423/500: train_loss=0.1930, val_loss=0.6199
# Epoch 424/500: train_loss=0.1932, val_loss=0.6202
# Epoch 425/500: train_loss=0.1932, val_loss=0.6201
# Epoch 426/500: train_loss=0.1962, val_loss=0.6232
# Epoch 427/500: train_loss=0.1942, val_loss=0.6232
# Epoch 428/500: train_loss=0.1954, val_loss=0.6221
# Epoch 429/500: train_loss=0.1952, val_loss=0.6219
# Epoch 430/500: train_loss=0.1949, val_loss=0.6225
# Epoch 431/500: train_loss=0.1932, val_loss=0.6205
# Epoch 432/500: train_loss=0.1924, val_loss=0.6218
# Epoch 433/500: train_loss=0.1925, val_loss=0.6212
# Epoch 434/500: train_loss=0.1944, val_loss=0.6226
# Epoch 435/500: train_loss=0.1958, val_loss=0.6224
# Epoch 436/500: train_loss=0.1934, val_loss=0.6218
# Epoch 437/500: train_loss=0.1937, val_loss=0.6225
# Epoch 438/500: train_loss=0.1929, val_loss=0.6212
# Epoch 439/500: train_loss=0.1950, val_loss=0.6229
# Epoch 440/500: train_loss=0.1942, val_loss=0.6223
# Epoch 441/500: train_loss=0.1962, val_loss=0.6231
# Epoch 442/500: train_loss=0.1927, val_loss=0.6221
# Epoch 443/500: train_loss=0.1945, val_loss=0.6218
# Epoch 444/500: train_loss=0.1922, val_loss=0.6221
# Epoch 445/500: train_loss=0.1947, val_loss=0.6219
# Epoch 446/500: train_loss=0.1923, val_loss=0.6209
# Epoch 447/500: train_loss=0.1935, val_loss=0.6222
# Epoch 448/500: train_loss=0.1915, val_loss=0.6195
# Epoch 449/500: train_loss=0.1916, val_loss=0.6195
# Epoch 450/500: train_loss=0.1917, val_loss=0.6208
# Epoch 451/500: train_loss=0.1933, val_loss=0.6211
# Epoch 452/500: train_loss=0.1958, val_loss=0.6245
# Epoch 453/500: train_loss=0.1924, val_loss=0.6207
# Epoch 454/500: train_loss=0.1935, val_loss=0.6218
# Epoch 455/500: train_loss=0.1947, val_loss=0.6230
# Epoch 456/500: train_loss=0.1935, val_loss=0.6224
# Epoch 457/500: train_loss=0.1921, val_loss=0.6215
# Epoch 458/500: train_loss=0.1917, val_loss=0.6221
# Epoch 459/500: train_loss=0.1917, val_loss=0.6236
# Epoch 460/500: train_loss=0.1908, val_loss=0.6226
# Epoch 461/500: train_loss=0.1925, val_loss=0.6224
# Epoch 462/500: train_loss=0.1946, val_loss=0.6225
# Epoch 463/500: train_loss=0.1931, val_loss=0.6213
# Epoch 464/500: train_loss=0.1907, val_loss=0.6211
# Epoch 465/500: train_loss=0.1911, val_loss=0.6214
# Epoch 466/500: train_loss=0.1903, val_loss=0.6207
# Epoch 467/500: train_loss=0.1930, val_loss=0.6220
# Epoch 468/500: train_loss=0.1918, val_loss=0.6200
# Epoch 469/500: train_loss=0.1930, val_loss=0.6203
# Epoch 470/500: train_loss=0.1898, val_loss=0.6189
# Epoch 471/500: train_loss=0.1895, val_loss=0.6204
# Epoch 472/500: train_loss=0.1910, val_loss=0.6194
# Epoch 473/500: train_loss=0.1905, val_loss=0.6193
# Epoch 474/500: train_loss=0.1914, val_loss=0.6208
# Epoch 475/500: train_loss=0.1944, val_loss=0.6223
# Epoch 476/500: train_loss=0.1917, val_loss=0.6207
# Epoch 477/500: train_loss=0.1924, val_loss=0.6220
# Epoch 478/500: train_loss=0.1924, val_loss=0.6221
# Epoch 479/500: train_loss=0.1914, val_loss=0.6206
# Epoch 480/500: train_loss=0.1892, val_loss=0.6201
# Epoch 481/500: train_loss=0.1913, val_loss=0.6202
# Epoch 482/500: train_loss=0.1924, val_loss=0.6223
# Epoch 483/500: train_loss=0.1903, val_loss=0.6216
# Epoch 484/500: train_loss=0.1908, val_loss=0.6213
# Epoch 485/500: train_loss=0.1912, val_loss=0.6206
# Epoch 486/500: train_loss=0.1889, val_loss=0.6200
# Epoch 487/500: train_loss=0.1909, val_loss=0.6214
# Epoch 488/500: train_loss=0.1898, val_loss=0.6215
# Epoch 489/500: train_loss=0.1888, val_loss=0.6196
# Epoch 490/500: train_loss=0.1877, val_loss=0.6199
# Epoch 491/500: train_loss=0.1871, val_loss=0.6203
# Epoch 492/500: train_loss=0.1880, val_loss=0.6216
# Epoch 493/500: train_loss=0.1891, val_loss=0.6207
# Epoch 494/500: train_loss=0.1870, val_loss=0.6198
# Epoch 495/500: train_loss=0.1879, val_loss=0.6201
# Epoch 496/500: train_loss=0.1876, val_loss=0.6186
# Epoch 497/500: train_loss=0.1889, val_loss=0.6205
# Epoch 498/500: train_loss=0.1919, val_loss=0.6214
# Epoch 499/500: train_loss=0.1888, val_loss=0.6210
# Epoch 500/500: train_loss=0.1874, val_loss=0.6191

# %% [markdown]
# Let us try to observe the trend of the training and validation losses. Going down together is better!

# %%
import matplotlib.pyplot as plt

plt.plot(range(epochs), history['train_losses'], label='train_loss')
plt.plot(range(epochs), history['val_losses'], label='val_loss')
plt.plot(history['best_epoch'], history['val_losses'][history['best_epoch']], marker='*')
plt.legend()
plt.show()

# %% [markdown]
# **Warning**: The common mistake with programmers is that they forgot to save the model at the best validation loss (minimum val_loss). The `history` variable tracks the best model.

# %% [markdown]
# Now, let us try to validate our model using the validation set. Notice that we use the `X_val` and `y_val`.

# %%
from sklearn import metrics

best_model = history['best_model']
y_val_pred = best_model.predict(X_val)
print(f"{metrics.classification_report(y_val, y_val_pred)}")
metrics.ConfusionMatrixDisplay.from_predictions(y_val, y_val_pred)
# Out:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.75      0.50      0.60        12
#      Colin Powell       0.86      0.91      0.89        35
#   Donald Rumsfeld       0.75      0.83      0.79        18
#     George W Bush       0.89      0.94      0.91        79
# Gerhard Schroeder       0.90      0.53      0.67        17
#       Hugo Chavez       0.64      0.64      0.64        11
#        Tony Blair       0.79      0.90      0.84        21
#
#          accuracy                           0.84       193
#         macro avg       0.80      0.75      0.76       193
#      weighted avg       0.84      0.84      0.83       193

# %% [markdown]
# ## 3. Testing
#
# Let us evaluate our best model using the testing set `X_test` and `y_test`.

# %%
y_test_pred = best_model.predict(X_test)
print(f"{metrics.classification_report(y_test, y_test_pred)}")
metrics.ConfusionMatrixDisplay.from_predictions(y_test, y_test_pred)
# Out:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.89      0.73      0.80        11
#      Colin Powell       0.75      0.92      0.82        36
#   Donald Rumsfeld       0.67      0.63      0.65        19
#     George W Bush       0.91      0.88      0.89        80
# Gerhard Schroeder       0.71      0.75      0.73        16
#       Hugo Chavez       0.70      0.70      0.70        10
#        Tony Blair       0.74      0.64      0.68        22
#
#          accuracy                           0.80       194
#         macro avg       0.77      0.75      0.75       194
#      weighted avg       0.81      0.80      0.80       194

# %% [markdown]
# Note: Do not forget to save your model offline.

# %%
import joblib

joblib.dump(best_model, 'mlp_model_e3.pkl')
# Out:
# ['mlp_model_e3.pkl']

# %% [markdown]
# ## 4. Deployment
#
# When deploying your system, you are not required to re-run the training, but you just need to run feedforward prediction using the saved model.

# %%
import joblib
import numpy as np

# Load trained model
loaded_model = joblib.load('mlp_model_e3.pkl')

# New sample (8x8 = 64 features)
x_new = [
    0,  0,  0,  5,  9,  0,  0,  0,
    0,  0,  2, 14, 14, 22,  0,  0,
    0,  0,  6, 14, 11,  9,  0,  0,
    0,  3, 15,  3, 11,  5,  0,  0,
    0,  8, 11,  0, 13,  6,  2,  0,
    6, 10, 16, 16, 12, 15, 17,  0,
    0,  0,  4, 10, 15,  3,  0,  0,
    0,  0,  0, 11, 13,  2,  0,  0
]

# Convert to numpy array
x_new = np.array(x_new).reshape(1, -1)   # shape = (1, 64)

# --- Fix shape mismatch ---
# Pad with zeros to match the model's expected number of features
expected_features = loaded_model.n_features_in_
if x_new.shape[1] < expected_features:
    # Pad zeros on the right
    x_new = np.pad(x_new, ((0, 0), (0, expected_features - x_new.shape[1])), mode='constant')

elif x_new.shape[1] > expected_features:
    # Trim extra features if too many
    x_new = x_new[:, :expected_features]

# Predict
y_new_pred = loaded_model.predict(x_new)
print(f"Predicted digit = {y_new_pred[0]}")
# Out:
# Predicted digit = Ariel Sharon
# c:\Users\DWIGHT LANCE JUMAOAS\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but PassiveAggressiveClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# **Challenge**: Try to run this [Python script](https://drive.google.com/file/d/1TkXU8jfWE03bb_N2AUL5_C9Y_vM1Kj7q/view?usp=drive_link) in offline mode, not here in Google Colab. Note that the file is the Python script from Laboratory 2. However, make sure to place both Python script and trained model (`mlp_model_e3.pkl`) in the same directory. Also, change the line that loads the model, overwrite with `mlp_model_e3.pkl`.

# %%
# End of laboratory notebook. Nothing follows ...
